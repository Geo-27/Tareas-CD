# %% [markdown]
# # Gestión Básica de Inventario con SQLite3
#
# **Autor: Elias Buitrago B.**\
# Bogotá, Colombia \
# Actualizado: 22 abril 202a \
# _Nota: Código ajustado para su ejecución en Google Colaboratory_\

# %% [markdown]
# ## Instalar librerías SQLite3

# %%
# %%shell
# sudo apt-get install sqlite3
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   sqlite3-doc
# The following NEW packages will be installed:
#   sqlite3
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 769 kB of archives.
# After this operation, 1,874 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 sqlite3 amd64 3.37.2-2ubuntu0.5 [769 kB]
# Fetched 769 kB in 1s (1,073 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package sqlite3.
# (Reading database ... 126718 files and directories currently installed.)
# Preparing to unpack .../sqlite3_3.37.2-2ubuntu0.5_amd64.deb ...
# Unpacking sqlite3 (3.37.2-2ubuntu0.5) ...
# Setting up sqlite3 (3.37.2-2ubuntu0.5) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# ## Crear la base de datos y una tabla de inventario

# %%
import sqlite3
import random

# Crear la base de datos con SQlite
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# %%
# Crear una tabla llamada 'inventario'
c.execute('''
CREATE TABLE inventario (
    id INTEGER PRIMARY KEY,
    nombre TEXT,
    categoria TEXT,
    precio DECIMAL(10, 2),
    cantidad INTEGER,
    proveedor TEXT,
    fecha_ingreso DATE,
    ubicacion TEXT
)
''')

# %%
# Generar datos de ejemplo para la tabla
def generar_producto(id):
    nombres = ["Producto", "Artículo", "Objeto"]
    categorias = ["Electrónica", "Hogar", "Jardín", "Moda", "Deportes"]
    proveedores = ["Proveedor1", "Proveedor2", "Proveedor3"]
    ubicaciones = ["Almacén A", "Almacén B", "Almacén C"]

    nombre = random.choice(nombres) + str(id)
    categoria = random.choice(categorias)
    precio = round(random.uniform(10.0, 500.0), 2)
    cantidad = random.randint(1, 100)
    proveedor = random.choice(proveedores)
    fecha_ingreso = f"2023-{random.randint(1, 12):02d}-{random.randint(1, 28):02d}"
    ubicacion = random.choice(ubicaciones)

    return (id, nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)

# Insertar 1000 productos en la tabla
productos = [generar_producto(i + 1) for i in range(10000)]
c.executemany('INSERT INTO inventario VALUES (?, ?, ?, ?, ?, ?, ?, ?)', productos)

# Guardar cambios y cerrar la conexión
conn.commit()
conn.close()

# %%
print("Base de datos creada y poblada con éxito.")
# Out:
# Base de datos creada y poblada con éxito.

# %% [markdown]
# ## Consulta para mostrar todos los productos creados

# %%
import sqlite3

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Consultar todos los productos
c.execute('SELECT * FROM inventario')
productos = c.fetchall()

# Imprimir los productos
for producto in productos:
    print(producto)

# Cerrar la conexión
conn.close()
# Out:
# (1, 'Artículo1', 'Hogar', 251.16, 97, 'Proveedor2', '2023-06-28', 'Almacén B')
# (2, 'Artículo2', 'Jardín', 133.17, 3, 'Proveedor3', '2023-10-03', 'Almacén A')
# (3, 'Producto3', 'Hogar', 283.89, 17, 'Proveedor1', '2023-11-12', 'Almacén C')
# (4, 'Artículo4', 'Moda', 497.15, 7, 'Proveedor2', '2023-04-07', 'Almacén C')
# (5, 'Producto5', 'Deportes', 351.12, 40, 'Proveedor1', '2023-08-19', 'Almacén B')
# (6, 'Producto6', 'Jardín', 261.42, 88, 'Proveedor3', '2023-08-04', 'Almacén A')
# (7, 'Producto7', 'Hogar', 116.39, 55, 'Proveedor2', '2023-10-19', 'Almacén C')
# (8, 'Objeto8', 'Deportes', 58.47, 86, 'Proveedor3', '2023-05-17', 'Almacén A')
# (9, 'Producto9', 'Deportes', 410.31, 5, 'Proveedor3', '2023-09-18', 'Almacén A')
# (10, 'Artículo10', 'Hogar', 398.66, 84, 'Proveedor1', '2023-01-14', 'Almacén B')
# (11, 'Objeto11', 'Jardín', 137.61, 94, 'Proveedor3', '2023-09-05', 'Almacén C')
# (12, 'Producto12', 'Moda', 174.95, 49, 'Proveedor2', '2023-02-18', 'Almacén B')
# (13, 'Artículo13', 'Deportes', 46.46, 39, 'Proveedor2', '2023-11-17', 'Almacén C')
# (14, 'Objeto14', 'Moda', 249.18, 59, 'Proveedor2', '2023-12-22', 'Almacén C')
# (15, 'Producto15', 'Jardín', 252.79, 94, 'Proveedor3', '2023-06-21', 'Almacén A')
# (16, 'Artículo16', 'Hogar', 431.97, 87, 'Proveedor2', '2023-02-25', 'Almacén B')
# (17, 'Artículo17', 'Electrónica', 195.27, 60, 'Proveedor2', '2023-09-13', 'Almacén C')
# (18, 'Objeto18', 'Deportes', 247.28, 10, 'Proveedor2', '2023-06-25', 'Almacén A')
# (19, 'Objeto19', 'Hogar', 14.66, 3, 'Proveedor2', '2023-04-04', 'Almacén C')
# (20, 'Objeto20', 'Jardín', 106.36, 90, 'Proveedor3', '2023-07-12', 'Almacén B')
# (21, 'Objeto21', 'Deportes', 265.19, 100, 'Proveedor1', '2023-10-10', 'Almacén C')
# (22, 'Producto22', 'Deportes', 197.25, 22, 'Proveedor1', '2023-10-22', 'Almacén C')
# (23, 'Producto23', 'Moda', 38.29, 76, 'Proveedor3', '2023-06-25', 'Almacén C')
# (24, 'Artículo24', 'Jardín', 322.03, 3, 'Proveedor1', '2023-08-02', 'Almacén B')
# (25, 'Artículo25', 'Deportes', 224.11, 54, 'Proveedor3', '2023-02-09', 'Almacén B')
# (26, 'Artículo26', 'Jardín', 191.99, 34, 'Proveedor2', '2023-02-07', 'Almacén A')
# (27, 'Objeto27', 'Deportes', 79.43, 88, 'Proveedor2', '2023-05-12', 'Almacén B')
# (28, 'Objeto28', 'Jardín', 116.06, 30, 'Proveedor3', '2023-09-05', 'Almacén A')
# (29, 'Producto29', 'Jardín', 24.77, 99, 'Proveedor2', '2023-11-17', 'Almacén A')
# (30, 'Objeto30', 'Deportes', 264.03, 80, 'Proveedor1', '2023-05-08', 'Almacén B')
# (31, 'Artículo31', 'Jardín', 415.48, 26, 'Proveedor2', '2023-06-12', 'Almacén C')
# (32, 'Objeto32', 'Deportes', 206.08, 59, 'Proveedor2', '2023-02-10', 'Almacén A')
# (33, 'Producto33', 'Moda', 493.92, 46, 'Proveedor3', '2023-04-12', 'Almacén C')
# (34, 'Producto34', 'Moda', 32.58, 94, 'Proveedor3', '2023-03-14', 'Almacén A')
# (35, 'Objeto35', 'Jardín', 385.25, 8, 'Proveedor2', '2023-08-12', 'Almacén B')
# (36, 'Objeto36', 'Hogar', 67.41, 60, 'Proveedor2', '2023-03-03', 'Almacén A')
# (37, 'Artículo37', 'Moda', 233.72, 39, 'Proveedor1', '2023-07-24', 'Almacén A')
# (38, 'Objeto38', 'Hogar', 123.4, 31, 'Proveedor3', '2023-06-10', 'Almacén B')
# (39, 'Artículo39', 'Moda', 19.21, 3, 'Proveedor3', '2023-03-23', 'Almacén C')
# (40, 'Objeto40', 'Deportes', 116.39, 56, 'Proveedor3', '2023-11-07', 'Almacén B')
# (41, 'Producto41', 'Deportes', 309.75, 13, 'Proveedor3', '2023-08-07', 'Almacén C')
# (42, 'Producto42', 'Hogar', 379.74, 56, 'Proveedor2', '2023-08-22', 'Almacén A')
# (43, 'Objeto43', 'Deportes', 383.85, 42, 'Proveedor2', '2023-12-01', 'Almacén A')
# (44, 'Objeto44', 'Deportes', 103.45, 7, 'Proveedor1', '2023-11-02', 'Almacén C')
# (45, 'Objeto45', 'Hogar', 441.41, 69, 'Proveedor2', '2023-03-12', 'Almacén C')
# (46, 'Objeto46', 'Electrónica', 373.22, 100, 'Proveedor3', '2023-08-26', 'Almacén C')
# (47, 'Artículo47', 'Jardín', 143.95, 27, 'Proveedor2', '2023-05-23', 'Almacén A')
# (48, 'Objeto48', 'Deportes', 162.3, 88, 'Proveedor1', '2023-04-05', 'Almacén B')
# (49, 'Artículo49', 'Moda', 87, 62, 'Proveedor3', '2023-07-05', 'Almacén A')
# (50, 'Producto50', 'Deportes', 99.68, 62, 'Proveedor2', '2023-06-02', 'Almacén A')
# (51, 'Objeto51', 'Hogar', 475.95, 70, 'Proveedor2', '2023-04-07', 'Almacén B')
# (52, 'Producto52', 'Moda', 204.4, 39, 'Proveedor2', '2023-10-12', 'Almacén B')
# (53, 'Producto53', 'Moda', 405.18, 24, 'Proveedor2', '2023-04-11', 'Almacén B')
# (54, 'Objeto54', 'Electrónica', 226.29, 79, 'Proveedor3', '2023-05-23', 'Almacén A')
# (55, 'Artículo55', 'Jardín', 318.05, 84, 'Proveedor1', '2023-03-27', 'Almacén B')
# (56, 'Artículo56', 'Electrónica', 290.16, 9, 'Proveedor2', '2023-10-13', 'Almacén B')
# (57, 'Artículo57', 'Deportes', 366.22, 60, 'Proveedor3', '2023-12-08', 'Almacén C')
# (58, 'Objeto58', 'Electrónica', 441.62, 79, 'Proveedor3', '2023-04-17', 'Almacén C')
# (59, 'Artículo59', 'Jardín', 207.06, 77, 'Proveedor2', '2023-10-20', 'Almacén A')
# (60, 'Artículo60', 'Hogar', 188.97, 52, 'Proveedor2', '2023-01-26', 'Almacén B')
# (61, 'Producto61', 'Jardín', 409.53, 74, 'Proveedor1', '2023-02-06', 'Almacén A')
# (62, 'Objeto62', 'Electrónica', 391.92, 64, 'Proveedor1', '2023-11-15', 'Almacén B')
# (63, 'Objeto63', 'Moda', 114.66, 17, 'Proveedor2', '2023-07-28', 'Almacén A')
# (64, 'Objeto64', 'Deportes', 238.19, 59, 'Proveedor2', '2023-07-13', 'Almacén B')
# (65, 'Artículo65', 'Jardín', 401.01, 74, 'Proveedor2', '2023-02-08', 'Almacén C')
# (66, 'Artículo66', 'Hogar', 435.93, 45, 'Proveedor2', '2023-03-17', 'Almacén A')
# (67, 'Artículo67', 'Hogar', 338.3, 14, 'Proveedor2', '2023-09-16', 'Almacén C')
# (68, 'Artículo68', 'Deportes', 59.89, 1, 'Proveedor1', '2023-06-13', 'Almacén B')
# (69, 'Producto69', 'Electrónica', 446.18, 52, 'Proveedor1', '2023-09-01', 'Almacén B')
# (70, 'Producto70', 'Deportes', 164.26, 40, 'Proveedor2', '2023-06-21', 'Almacén B')
# (71, 'Objeto71', 'Moda', 392.16, 16, 'Proveedor1', '2023-08-17', 'Almacén A')
# (72, 'Objeto72', 'Jardín', 170.64, 58, 'Proveedor2', '2023-02-16', 'Almacén B')
# (73, 'Objeto73', 'Deportes', 313.09, 41, 'Proveedor3', '2023-03-21', 'Almacén A')
# (74, 'Artículo74', 'Jardín', 166.72, 45, 'Proveedor3', '2023-10-07', 'Almacén A')
# (75, 'Producto75', 'Electrónica', 192.59, 47, 'Proveedor1', '2023-12-07', 'Almacén A')
# (76, 'Objeto76', 'Electrónica', 288.52, 50, 'Proveedor2', '2023-05-07', 'Almacén C')
# (77, 'Artículo77', 'Hogar', 113.7, 64, 'Proveedor3', '2023-11-22', 'Almacén A')
# (78, 'Producto78', 'Moda', 21.57, 63, 'Proveedor2', '2023-11-18', 'Almacén C')
# (79, 'Producto79', 'Electrónica', 271.57, 84, 'Proveedor3', '2023-12-14', 'Almacén C')
# (80, 'Producto80', 'Deportes', 317.67, 60, 'Proveedor3', '2023-05-10', 'Almacén A')
# (81, 'Artículo81', 'Jardín', 480.18, 64, 'Proveedor3', '2023-05-25', 'Almacén A')
# (82, 'Artículo82', 'Electrónica', 198.03, 89, 'Proveedor1', '2023-10-18', 'Almacén C')
# (83, 'Producto83', 'Moda', 186.29, 48, 'Proveedor2', '2023-06-02', 'Almacén C')
# (84, 'Producto84', 'Hogar', 396.95, 32, 'Proveedor3', '2023-06-12', 'Almacén B')
# (85, 'Artículo85', 'Hogar', 323.34, 33, 'Proveedor3', '2023-02-08', 'Almacén B')
# (86, 'Producto86', 'Hogar', 107.54, 7, 'Proveedor3', '2023-02-20', 'Almacén A')
# (87, 'Producto87', 'Jardín', 190.81, 56, 'Proveedor3', '2023-07-15', 'Almacén A')
# (88, 'Artículo88', 'Hogar', 275.87, 54, 'Proveedor2', '2023-11-20', 'Almacén B')
# (89, 'Objeto89', 'Hogar', 467.15, 48, 'Proveedor3', '2023-10-18', 'Almacén B')
# (90, 'Objeto90', 'Hogar', 430.05, 45, 'Proveedor1', '2023-02-25', 'Almacén C')
# (91, 'Artículo91', 'Jardín', 358.33, 70, 'Proveedor1', '2023-04-04', 'Almacén B')
# (92, 'Artículo92', 'Moda', 178.4, 99, 'Proveedor2', '2023-11-24', 'Almacén C')
# (93, 'Producto93', 'Jardín', 23.88, 26, 'Proveedor1', '2023-05-03', 'Almacén A')
# (94, 'Objeto94', 'Hogar', 93.44, 63, 'Proveedor3', '2023-10-11', 'Almacén A')
# (95, 'Artículo95', 'Deportes', 225.87, 27, 'Proveedor2', '2023-03-13', 'Almacén B')
# (96, 'Artículo96', 'Moda', 42.09, 11, 'Proveedor2', '2023-12-21', 'Almacén B')
# (97, 'Producto97', 'Jardín', 227.24, 86, 'Proveedor2', '2023-07-11', 'Almacén A')
# (98, 'Artículo98', 'Electrónica', 126.95, 65, 'Proveedor3', '2023-08-09', 'Almacén A')
# (99, 'Producto99', 'Deportes', 251.59, 22, 'Proveedor2', '2023-12-05', 'Almacén B')
# (100, 'Producto100', 'Deportes', 100.6, 29, 'Proveedor3', '2023-11-03', 'Almacén A')
# (101, 'Objeto101', 'Moda', 288.27, 4, 'Proveedor1', '2023-10-11', 'Almacén A')
# (102, 'Producto102', 'Deportes', 297.8, 67, 'Proveedor1', '2023-05-18', 'Almacén B')
# (103, 'Artículo103', 'Moda', 239.54, 20, 'Proveedor1', '2023-08-04', 'Almacén A')
# (104, 'Producto104', 'Deportes', 233.97, 34, 'Proveedor3', '2023-11-12', 'Almacén A')
# (105, 'Artículo105', 'Moda', 213.04, 51, 'Proveedor2', '2023-12-02', 'Almacén B')
# (106, 'Artículo106', 'Moda', 292.48, 98, 'Proveedor1', '2023-11-11', 'Almacén C')
# (107, 'Artículo107', 'Electrónica', 16.68, 68, 'Proveedor3', '2023-09-03', 'Almacén B')
# (108, 'Objeto108', 'Deportes', 213.88, 1, 'Proveedor1', '2023-03-10', 'Almacén A')
# (109, 'Objeto109', 'Hogar', 479.75, 93, 'Proveedor3', '2023-09-27', 'Almacén C')
# (110, 'Artículo110', 'Hogar', 252.19, 35, 'Proveedor1', '2023-11-10', 'Almacén C')
# (111, 'Artículo111', 'Moda', 65.96, 74, 'Proveedor3', '2023-05-16', 'Almacén B')
# (112, 'Objeto112', 'Moda', 298.79, 70, 'Proveedor2', '2023-12-01', 'Almacén B')
# (113, 'Objeto113', 'Electrónica', 358.71, 59, 'Proveedor2', '2023-02-27', 'Almacén B')
# (114, 'Producto114', 'Jardín', 98.01, 34, 'Proveedor2', '2023-11-09', 'Almacén C')
# (115, 'Producto115', 'Hogar', 326.07, 42, 'Proveedor1', '2023-04-03', 'Almacén C')
# (116, 'Artículo116', 'Hogar', 170.52, 90, 'Proveedor1', '2023-01-04', 'Almacén C')
# (117, 'Artículo117', 'Jardín', 277.84, 26, 'Proveedor2', '2023-07-01', 'Almacén C')
# (118, 'Producto118', 'Deportes', 409.34, 47, 'Proveedor1', '2023-04-17', 'Almacén C')
# (119, 'Artículo119', 'Deportes', 248.26, 88, 'Proveedor3', '2023-01-25', 'Almacén B')
# (120, 'Producto120', 'Electrónica', 124.75, 97, 'Proveedor3', '2023-08-26', 'Almacén C')
# (121, 'Objeto121', 'Moda', 130.32, 2, 'Proveedor1', '2023-04-23', 'Almacén C')
# (122, 'Producto122', 'Electrónica', 474.68, 90, 'Proveedor2', '2023-10-08', 'Almacén A')
# (123, 'Producto123', 'Electrónica', 129.21, 4, 'Proveedor2', '2023-03-20', 'Almacén A')
# (124, 'Producto124', 'Jardín', 137.19, 90, 'Proveedor3', '2023-07-09', 'Almacén A')
# (125, 'Artículo125', 'Deportes', 38.49, 7, 'Proveedor3', '2023-03-08', 'Almacén A')
# (126, 'Producto126', 'Hogar', 169.57, 77, 'Proveedor2', '2023-06-07', 'Almacén A')
# (127, 'Objeto127', 'Hogar', 378.16, 48, 'Proveedor1', '2023-11-03', 'Almacén A')
# (128, 'Artículo128', 'Moda', 84, 3, 'Proveedor2', '2023-01-02', 'Almacén C')
# (129, 'Artículo129', 'Deportes', 432.45, 54, 'Proveedor3', '2023-09-14', 'Almacén A')
# (130, 'Producto130', 'Moda', 343.73, 47, 'Proveedor1', '2023-03-06', 'Almacén A')
# (131, 'Objeto131', 'Moda', 48.21, 77, 'Proveedor3', '2023-06-15', 'Almacén A')
# (132, 'Objeto132', 'Hogar', 384.77, 81, 'Proveedor1', '2023-08-09', 'Almacén C')
# (133, 'Objeto133', 'Jardín', 294.5, 19, 'Proveedor1', '2023-07-26', 'Almacén B')
# (134, 'Objeto134', 'Moda', 438.93, 50, 'Proveedor1', '2023-02-12', 'Almacén A')
# (135, 'Objeto135', 'Moda', 215.91, 97, 'Proveedor2', '2023-05-19', 'Almacén C')
# (136, 'Artículo136', 'Hogar', 20.69, 46, 'Proveedor2', '2023-06-07', 'Almacén C')
# (137, 'Producto137', 'Hogar', 68.38, 98, 'Proveedor1', '2023-02-21', 'Almacén C')
# (138, 'Objeto138', 'Moda', 494.07, 72, 'Proveedor1', '2023-03-11', 'Almacén A')
# (139, 'Objeto139', 'Hogar', 262.81, 64, 'Proveedor3', '2023-05-07', 'Almacén B')
# (140, 'Artículo140', 'Electrónica', 407.1, 55, 'Proveedor1', '2023-10-17', 'Almacén A')
# (141, 'Artículo141', 'Electrónica', 433.63, 50, 'Proveedor3', '2023-01-08', 'Almacén B')
# (142, 'Objeto142', 'Deportes', 170.31, 68, 'Proveedor2', '2023-01-21', 'Almacén C')
# (143, 'Artículo143', 'Hogar', 34.9, 74, 'Proveedor3', '2023-08-03', 'Almacén B')
# (144, 'Producto144', 'Hogar', 130.6, 96, 'Proveedor3', '2023-03-22', 'Almacén B')
# (145, 'Artículo145', 'Deportes', 429.07, 75, 'Proveedor2', '2023-07-06', 'Almacén C')
# (146, 'Producto146', 'Jardín', 396.9, 97, 'Proveedor3', '2023-11-07', 'Almacén A')
# (147, 'Objeto147', 'Moda', 192.39, 19, 'Proveedor1', '2023-03-22', 'Almacén B')
# (148, 'Producto148', 'Moda', 378.18, 24, 'Proveedor2', '2023-09-08', 'Almacén C')
# (149, 'Producto149', 'Moda', 179.72, 13, 'Proveedor2', '2023-08-08', 'Almacén A')
# (150, 'Artículo150', 'Hogar', 293.72, 54, 'Proveedor3', '2023-09-05', 'Almacén B')
# (151, 'Artículo151', 'Electrónica', 329.69, 47, 'Proveedor1', '2023-01-04', 'Almacén B')
# (152, 'Artículo152', 'Hogar', 224.86, 87, 'Proveedor1', '2023-01-19', 'Almacén B')
# (153, 'Producto153', 'Electrónica', 138.86, 22, 'Proveedor1', '2023-09-26', 'Almacén A')
# (154, 'Artículo154', 'Deportes', 138.59, 15, 'Proveedor2', '2023-07-14', 'Almacén C')
# (155, 'Artículo155', 'Hogar', 163.81, 81, 'Proveedor2', '2023-06-03', 'Almacén A')
# (156, 'Producto156', 'Jardín', 376.44, 77, 'Proveedor3', '2023-04-14', 'Almacén C')
# (157, 'Artículo157', 'Moda', 214.19, 48, 'Proveedor2', '2023-12-20', 'Almacén B')
# (158, 'Producto158', 'Hogar', 151.94, 3, 'Proveedor2', '2023-07-14', 'Almacén B')
# (159, 'Producto159', 'Electrónica', 244.88, 24, 'Proveedor3', '2023-04-18', 'Almacén B')
# (160, 'Producto160', 'Hogar', 454.9, 50, 'Proveedor3', '2023-09-24', 'Almacén B')
# (161, 'Artículo161', 'Electrónica', 45.65, 7, 'Proveedor1', '2023-03-16', 'Almacén C')
# (162, 'Objeto162', 'Moda', 22.98, 36, 'Proveedor2', '2023-05-25', 'Almacén A')
# (163, 'Objeto163', 'Moda', 88.41, 86, 'Proveedor1', '2023-01-22', 'Almacén A')
# (164, 'Artículo164', 'Electrónica', 107.52, 75, 'Proveedor1', '2023-10-02', 'Almacén B')
# (165, 'Artículo165', 'Deportes', 18.53, 89, 'Proveedor3', '2023-04-20', 'Almacén A')
# (166, 'Producto166', 'Jardín', 237.09, 60, 'Proveedor3', '2023-03-08', 'Almacén A')
# (167, 'Objeto167', 'Deportes', 446.52, 71, 'Proveedor3', '2023-11-02', 'Almacén A')
# (168, 'Artículo168', 'Electrónica', 197.76, 59, 'Proveedor1', '2023-02-18', 'Almacén A')
# (169, 'Artículo169', 'Moda', 453.73, 35, 'Proveedor3', '2023-05-17', 'Almacén B')
# (170, 'Objeto170', 'Deportes', 138.91, 45, 'Proveedor2', '2023-04-07', 'Almacén C')
# (171, 'Artículo171', 'Electrónica', 408.13, 18, 'Proveedor3', '2023-12-26', 'Almacén A')
# (172, 'Producto172', 'Moda', 231.87, 73, 'Proveedor1', '2023-08-04', 'Almacén B')
# (173, 'Producto173', 'Electrónica', 160.27, 50, 'Proveedor3', '2023-11-19', 'Almacén B')
# (174, 'Artículo174', 'Electrónica', 469.72, 11, 'Proveedor2', '2023-01-21', 'Almacén C')
# (175, 'Artículo175', 'Moda', 398.26, 17, 'Proveedor3', '2023-01-20', 'Almacén B')
# (176, 'Artículo176', 'Deportes', 189.3, 78, 'Proveedor1', '2023-07-22', 'Almacén B')
# (177, 'Objeto177', 'Hogar', 498.21, 100, 'Proveedor2', '2023-02-05', 'Almacén C')
# (178, 'Artículo178', 'Deportes', 278.24, 94, 'Proveedor1', '2023-01-13', 'Almacén C')
# (179, 'Artículo179', 'Hogar', 107.95, 60, 'Proveedor3', '2023-05-28', 'Almacén C')
# (180, 'Objeto180', 'Hogar', 483.35, 8, 'Proveedor3', '2023-01-21', 'Almacén B')
# (181, 'Producto181', 'Hogar', 459, 78, 'Proveedor1', '2023-02-03', 'Almacén C')
# (182, 'Objeto182', 'Hogar', 142.1, 64, 'Proveedor1', '2023-04-21', 'Almacén A')
# (183, 'Producto183', 'Electrónica', 433.65, 65, 'Proveedor3', '2023-02-25', 'Almacén B')
# (184, 'Producto184', 'Electrónica', 395.99, 37, 'Proveedor2', '2023-10-07', 'Almacén B')
# (185, 'Artículo185', 'Jardín', 397.22, 41, 'Proveedor2', '2023-01-06', 'Almacén C')
# (186, 'Objeto186', 'Jardín', 223.57, 67, 'Proveedor3', '2023-08-21', 'Almacén A')
# (187, 'Objeto187', 'Moda', 36.46, 69, 'Proveedor2', '2023-06-19', 'Almacén C')
# (188, 'Artículo188', 'Deportes', 293.81, 20, 'Proveedor3', '2023-12-21', 'Almacén B')
# (189, 'Artículo189', 'Electrónica', 94.58, 91, 'Proveedor2', '2023-12-13', 'Almacén B')
# (190, 'Artículo190', 'Jardín', 401.72, 53, 'Proveedor1', '2023-08-22', 'Almacén B')
# (191, 'Objeto191', 'Hogar', 423.16, 76, 'Proveedor1', '2023-05-10', 'Almacén B')
# (192, 'Artículo192', 'Deportes', 230.42, 13, 'Proveedor3', '2023-07-14', 'Almacén A')
# (193, 'Producto193', 'Deportes', 103.89, 4, 'Proveedor1', '2023-05-04', 'Almacén B')
# (194, 'Objeto194', 'Jardín', 129.85, 36, 'Proveedor3', '2023-06-16', 'Almacén B')
# (195, 'Objeto195', 'Hogar', 11.62, 23, 'Proveedor1', '2023-06-17', 'Almacén A')
# (196, 'Objeto196', 'Moda', 82.41, 58, 'Proveedor1', '2023-09-05', 'Almacén B')
# (197, 'Objeto197', 'Jardín', 45.7, 37, 'Proveedor2', '2023-06-22', 'Almacén B')
# (198, 'Artículo198', 'Electrónica', 205.56, 32, 'Proveedor2', '2023-10-05', 'Almacén B')
# (199, 'Producto199', 'Moda', 146.8, 1, 'Proveedor1', '2023-02-13', 'Almacén C')
# (200, 'Objeto200', 'Moda', 79.52, 32, 'Proveedor1', '2023-06-18', 'Almacén A')
# (201, 'Objeto201', 'Electrónica', 437.67, 98, 'Proveedor1', '2023-11-10', 'Almacén C')
# (202, 'Producto202', 'Moda', 377.14, 42, 'Proveedor3', '2023-05-27', 'Almacén A')
# (203, 'Artículo203', 'Jardín', 470.49, 53, 'Proveedor2', '2023-10-19', 'Almacén C')
# (204, 'Objeto204', 'Hogar', 275.46, 19, 'Proveedor1', '2023-01-18', 'Almacén B')
# (205, 'Artículo205', 'Hogar', 44.71, 35, 'Proveedor1', '2023-10-13', 'Almacén B')
# (206, 'Artículo206', 'Hogar', 267.33, 80, 'Proveedor2', '2023-05-06', 'Almacén A')
# (207, 'Objeto207', 'Deportes', 185.14, 9, 'Proveedor1', '2023-08-15', 'Almacén B')
# (208, 'Artículo208', 'Moda', 142.07, 25, 'Proveedor2', '2023-05-12', 'Almacén C')
# (209, 'Artículo209', 'Deportes', 86.61, 97, 'Proveedor2', '2023-11-05', 'Almacén B')
# (210, 'Artículo210', 'Hogar', 426.68, 90, 'Proveedor2', '2023-10-26', 'Almacén A')
# (211, 'Artículo211', 'Jardín', 208.29, 14, 'Proveedor2', '2023-12-12', 'Almacén B')
# (212, 'Objeto212', 'Jardín', 194.24, 17, 'Proveedor1', '2023-11-18', 'Almacén C')
# (213, 'Artículo213', 'Jardín', 300.05, 4, 'Proveedor2', '2023-04-10', 'Almacén B')
# (214, 'Producto214', 'Electrónica', 355.37, 84, 'Proveedor2', '2023-09-15', 'Almacén B')
# (215, 'Objeto215', 'Jardín', 156.31, 41, 'Proveedor3', '2023-06-10', 'Almacén C')
# (216, 'Producto216', 'Moda', 329.48, 49, 'Proveedor2', '2023-07-20', 'Almacén B')
# (217, 'Producto217', 'Moda', 102.81, 13, 'Proveedor2', '2023-09-28', 'Almacén A')
# (218, 'Artículo218', 'Electrónica', 111.05, 27, 'Proveedor1', '2023-04-07', 'Almacén A')
# (219, 'Artículo219', 'Moda', 12.15, 35, 'Proveedor1', '2023-01-01', 'Almacén C')
# (220, 'Producto220', 'Jardín', 407.81, 43, 'Proveedor3', '2023-12-08', 'Almacén A')
# (221, 'Producto221', 'Jardín', 271.43, 63, 'Proveedor3', '2023-03-25', 'Almacén B')
# (222, 'Artículo222', 'Jardín', 400.85, 85, 'Proveedor1', '2023-08-23', 'Almacén C')
# (223, 'Objeto223', 'Electrónica', 45.29, 46, 'Proveedor2', '2023-06-17', 'Almacén A')
# (224, 'Objeto224', 'Hogar', 181.52, 33, 'Proveedor1', '2023-06-20', 'Almacén A')
# (225, 'Artículo225', 'Electrónica', 313.02, 62, 'Proveedor3', '2023-04-05', 'Almacén C')
# (226, 'Producto226', 'Electrónica', 346.85, 88, 'Proveedor3', '2023-08-08', 'Almacén B')
# (227, 'Artículo227', 'Electrónica', 19.93, 80, 'Proveedor2', '2023-07-20', 'Almacén B')
# (228, 'Objeto228', 'Hogar', 249.28, 83, 'Proveedor3', '2023-11-19', 'Almacén C')
# (229, 'Producto229', 'Deportes', 456.01, 67, 'Proveedor2', '2023-09-19', 'Almacén B')
# (230, 'Producto230', 'Deportes', 53.38, 2, 'Proveedor1', '2023-01-22', 'Almacén B')
# (231, 'Producto231', 'Electrónica', 172.77, 2, 'Proveedor1', '2023-07-06', 'Almacén A')
# (232, 'Artículo232', 'Deportes', 364.07, 92, 'Proveedor3', '2023-03-05', 'Almacén C')
# (233, 'Producto233', 'Jardín', 194.06, 87, 'Proveedor2', '2023-03-28', 'Almacén C')
# (234, 'Artículo234', 'Electrónica', 265.63, 9, 'Proveedor3', '2023-03-11', 'Almacén B')
# (235, 'Artículo235', 'Jardín', 97.9, 21, 'Proveedor2', '2023-08-08', 'Almacén B')
# (236, 'Producto236', 'Deportes', 310.83, 67, 'Proveedor2', '2023-02-02', 'Almacén A')
# (237, 'Producto237', 'Jardín', 27.28, 34, 'Proveedor2', '2023-06-11', 'Almacén A')
# (238, 'Objeto238', 'Jardín', 360.56, 8, 'Proveedor2', '2023-03-13', 'Almacén C')
# (239, 'Artículo239', 'Jardín', 54.72, 44, 'Proveedor3', '2023-02-02', 'Almacén A')
# (240, 'Objeto240', 'Deportes', 184.66, 91, 'Proveedor1', '2023-11-22', 'Almacén B')
# (241, 'Artículo241', 'Deportes', 153.43, 65, 'Proveedor1', '2023-04-17', 'Almacén A')
# (242, 'Objeto242', 'Electrónica', 422.24, 84, 'Proveedor1', '2023-10-19', 'Almacén C')
# (243, 'Artículo243', 'Jardín', 21.02, 60, 'Proveedor3', '2023-05-20', 'Almacén A')
# (244, 'Objeto244', 'Moda', 215.88, 58, 'Proveedor3', '2023-03-16', 'Almacén B')
# (245, 'Artículo245', 'Moda', 64.01, 78, 'Proveedor3', '2023-11-11', 'Almacén B')
# (246, 'Artículo246', 'Moda', 439.85, 72, 'Proveedor2', '2023-01-18', 'Almacén B')
# (247, 'Producto247', 'Hogar', 377.42, 41, 'Proveedor2', '2023-11-02', 'Almacén C')
# (248, 'Objeto248', 'Jardín', 261.93, 33, 'Proveedor3', '2023-04-15', 'Almacén A')
# (249, 'Producto249', 'Deportes', 435.82, 79, 'Proveedor2', '2023-11-05', 'Almacén A')
# (250, 'Producto250', 'Moda', 109.84, 98, 'Proveedor1', '2023-10-24', 'Almacén A')
# (251, 'Artículo251', 'Jardín', 190.65, 32, 'Proveedor3', '2023-01-01', 'Almacén B')
# (252, 'Producto252', 'Moda', 238.16, 76, 'Proveedor3', '2023-11-18', 'Almacén A')
# (253, 'Producto253', 'Jardín', 189.78, 8, 'Proveedor1', '2023-07-04', 'Almacén A')
# (254, 'Objeto254', 'Jardín', 226.17, 69, 'Proveedor1', '2023-06-21', 'Almacén A')
# (255, 'Producto255', 'Hogar', 111.83, 8, 'Proveedor1', '2023-07-01', 'Almacén A')
# (256, 'Objeto256', 'Deportes', 399, 94, 'Proveedor3', '2023-11-18', 'Almacén B')
# (257, 'Artículo257', 'Hogar', 96.41, 9, 'Proveedor2', '2023-08-26', 'Almacén A')
# (258, 'Producto258', 'Deportes', 328.57, 70, 'Proveedor2', '2023-10-22', 'Almacén B')
# (259, 'Artículo259', 'Jardín', 58.1, 53, 'Proveedor1', '2023-01-24', 'Almacén C')
# (260, 'Artículo260', 'Jardín', 422.86, 24, 'Proveedor1', '2023-07-19', 'Almacén C')
# (261, 'Producto261', 'Electrónica', 467.22, 12, 'Proveedor3', '2023-05-17', 'Almacén B')
# (262, 'Objeto262', 'Deportes', 446.75, 63, 'Proveedor2', '2023-03-21', 'Almacén B')
# (263, 'Artículo263', 'Jardín', 256.66, 1, 'Proveedor3', '2023-02-28', 'Almacén A')
# (264, 'Artículo264', 'Moda', 126.81, 88, 'Proveedor1', '2023-05-08', 'Almacén C')
# (265, 'Artículo265', 'Hogar', 423.91, 42, 'Proveedor2', '2023-09-16', 'Almacén A')
# (266, 'Artículo266', 'Jardín', 391.56, 35, 'Proveedor2', '2023-07-03', 'Almacén B')
# (267, 'Producto267', 'Jardín', 262.38, 47, 'Proveedor2', '2023-02-27', 'Almacén A')
# (268, 'Objeto268', 'Moda', 469.32, 33, 'Proveedor3', '2023-08-14', 'Almacén A')
# (269, 'Producto269', 'Moda', 279.47, 95, 'Proveedor1', '2023-10-16', 'Almacén A')
# (270, 'Artículo270', 'Hogar', 283.11, 10, 'Proveedor3', '2023-11-07', 'Almacén C')
# (271, 'Artículo271', 'Electrónica', 258.4, 93, 'Proveedor1', '2023-12-25', 'Almacén B')
# (272, 'Producto272', 'Hogar', 252.84, 87, 'Proveedor2', '2023-07-26', 'Almacén A')
# (273, 'Objeto273', 'Jardín', 311.83, 52, 'Proveedor3', '2023-12-14', 'Almacén C')
# (274, 'Artículo274', 'Deportes', 281.93, 3, 'Proveedor1', '2023-05-04', 'Almacén B')
# (275, 'Producto275', 'Hogar', 186.2, 52, 'Proveedor3', '2023-05-01', 'Almacén B')
# (276, 'Objeto276', 'Hogar', 325.54, 34, 'Proveedor1', '2023-07-07', 'Almacén B')
# (277, 'Objeto277', 'Moda', 12.06, 98, 'Proveedor2', '2023-06-28', 'Almacén C')
# (278, 'Objeto278', 'Electrónica', 264.36, 36, 'Proveedor1', '2023-07-28', 'Almacén A')
# (279, 'Objeto279', 'Moda', 193.86, 71, 'Proveedor3', '2023-03-24', 'Almacén C')
# (280, 'Objeto280', 'Jardín', 363.57, 81, 'Proveedor1', '2023-04-25', 'Almacén C')
# (281, 'Producto281', 'Jardín', 222.77, 16, 'Proveedor3', '2023-06-05', 'Almacén B')
# (282, 'Objeto282', 'Electrónica', 219.02, 3, 'Proveedor2', '2023-10-09', 'Almacén C')
# (283, 'Producto283', 'Electrónica', 118.85, 83, 'Proveedor3', '2023-11-27', 'Almacén A')
# (284, 'Objeto284', 'Electrónica', 467.95, 18, 'Proveedor3', '2023-09-20', 'Almacén A')
# (285, 'Producto285', 'Hogar', 426.29, 3, 'Proveedor1', '2023-04-03', 'Almacén A')
# (286, 'Artículo286', 'Moda', 335.21, 12, 'Proveedor3', '2023-11-08', 'Almacén C')
# (287, 'Artículo287', 'Jardín', 290.81, 80, 'Proveedor3', '2023-06-10', 'Almacén C')
# (288, 'Artículo288', 'Moda', 141.24, 66, 'Proveedor1', '2023-11-03', 'Almacén B')
# (289, 'Artículo289', 'Deportes', 371.35, 37, 'Proveedor3', '2023-11-16', 'Almacén C')
# (290, 'Artículo290', 'Electrónica', 196.64, 87, 'Proveedor2', '2023-02-06', 'Almacén B')
# (291, 'Artículo291', 'Electrónica', 365.13, 24, 'Proveedor1', '2023-07-20', 'Almacén C')
# (292, 'Objeto292', 'Deportes', 149.02, 100, 'Proveedor3', '2023-08-12', 'Almacén C')
# (293, 'Artículo293', 'Hogar', 100.6, 17, 'Proveedor2', '2023-01-02', 'Almacén A')
# (294, 'Producto294', 'Deportes', 74.53, 83, 'Proveedor2', '2023-10-15', 'Almacén A')
# (295, 'Artículo295', 'Electrónica', 356.44, 23, 'Proveedor3', '2023-11-12', 'Almacén C')
# (296, 'Objeto296', 'Moda', 293.03, 75, 'Proveedor1', '2023-08-03', 'Almacén C')
# (297, 'Artículo297', 'Electrónica', 285.81, 52, 'Proveedor1', '2023-03-18', 'Almacén B')
# (298, 'Artículo298', 'Moda', 48.22, 61, 'Proveedor2', '2023-06-13', 'Almacén A')
# (299, 'Producto299', 'Moda', 92.1, 73, 'Proveedor1', '2023-03-17', 'Almacén B')
# (300, 'Artículo300', 'Electrónica', 174.03, 50, 'Proveedor3', '2023-01-20', 'Almacén A')
# (301, 'Artículo301', 'Moda', 68.75, 81, 'Proveedor2', '2023-01-23', 'Almacén A')
# (302, 'Objeto302', 'Jardín', 241.13, 76, 'Proveedor3', '2023-10-03', 'Almacén B')
# (303, 'Artículo303', 'Deportes', 95.98, 47, 'Proveedor1', '2023-01-23', 'Almacén A')
# (304, 'Producto304', 'Jardín', 464.17, 51, 'Proveedor3', '2023-01-20', 'Almacén A')
# (305, 'Producto305', 'Moda', 23.03, 81, 'Proveedor1', '2023-09-20', 'Almacén B')
# (306, 'Producto306', 'Moda', 207.28, 13, 'Proveedor1', '2023-03-11', 'Almacén A')
# (307, 'Artículo307', 'Hogar', 56.37, 43, 'Proveedor3', '2023-04-17', 'Almacén C')
# (308, 'Objeto308', 'Moda', 220.88, 24, 'Proveedor1', '2023-09-03', 'Almacén A')
# (309, 'Artículo309', 'Electrónica', 243.78, 10, 'Proveedor1', '2023-11-06', 'Almacén B')
# (310, 'Artículo310', 'Jardín', 461.49, 24, 'Proveedor1', '2023-07-08', 'Almacén C')
# (311, 'Objeto311', 'Jardín', 272.62, 83, 'Proveedor2', '2023-03-28', 'Almacén C')
# (312, 'Objeto312', 'Hogar', 203.53, 64, 'Proveedor1', '2023-12-14', 'Almacén C')
# (313, 'Producto313', 'Electrónica', 31.18, 11, 'Proveedor2', '2023-09-22', 'Almacén A')
# (314, 'Producto314', 'Jardín', 361.18, 20, 'Proveedor2', '2023-03-27', 'Almacén C')
# (315, 'Objeto315', 'Jardín', 68.94, 27, 'Proveedor3', '2023-07-23', 'Almacén B')
# (316, 'Artículo316', 'Jardín', 381.79, 71, 'Proveedor2', '2023-11-18', 'Almacén A')
# (317, 'Producto317', 'Hogar', 120.66, 4, 'Proveedor2', '2023-10-10', 'Almacén B')
# (318, 'Producto318', 'Moda', 196.5, 59, 'Proveedor1', '2023-07-06', 'Almacén C')
# (319, 'Artículo319', 'Deportes', 96.95, 8, 'Proveedor3', '2023-01-07', 'Almacén A')
# (320, 'Objeto320', 'Electrónica', 170.66, 22, 'Proveedor1', '2023-06-11', 'Almacén C')
# (321, 'Artículo321', 'Moda', 291.7, 49, 'Proveedor1', '2023-06-05', 'Almacén B')
# (322, 'Producto322', 'Hogar', 362.34, 100, 'Proveedor1', '2023-12-02', 'Almacén C')
# (323, 'Producto323', 'Deportes', 109.81, 28, 'Proveedor2', '2023-07-19', 'Almacén A')
# (324, 'Producto324', 'Electrónica', 16.6, 56, 'Proveedor1', '2023-08-28', 'Almacén B')
# (325, 'Artículo325', 'Jardín', 362.78, 58, 'Proveedor2', '2023-11-24', 'Almacén C')
# (326, 'Producto326', 'Hogar', 358.4, 54, 'Proveedor3', '2023-10-08', 'Almacén A')
# (327, 'Artículo327', 'Moda', 247.44, 2, 'Proveedor1', '2023-10-01', 'Almacén C')
# (328, 'Artículo328', 'Electrónica', 208.27, 100, 'Proveedor2', '2023-10-23', 'Almacén A')
# (329, 'Artículo329', 'Moda', 289.17, 19, 'Proveedor3', '2023-11-19', 'Almacén A')
# (330, 'Artículo330', 'Electrónica', 151.06, 53, 'Proveedor2', '2023-05-08', 'Almacén C')
# (331, 'Artículo331', 'Moda', 51.98, 47, 'Proveedor2', '2023-04-20', 'Almacén C')
# (332, 'Producto332', 'Jardín', 431.85, 98, 'Proveedor2', '2023-02-28', 'Almacén C')
# (333, 'Producto333', 'Electrónica', 245.46, 50, 'Proveedor1', '2023-09-22', 'Almacén C')
# (334, 'Artículo334', 'Deportes', 52.82, 100, 'Proveedor2', '2023-06-09', 'Almacén C')
# (335, 'Objeto335', 'Electrónica', 148.49, 95, 'Proveedor3', '2023-03-05', 'Almacén B')
# (336, 'Artículo336', 'Hogar', 414.61, 30, 'Proveedor2', '2023-02-21', 'Almacén A')
# (337, 'Artículo337', 'Jardín', 166.95, 36, 'Proveedor1', '2023-04-05', 'Almacén A')
# (338, 'Objeto338', 'Jardín', 36.31, 28, 'Proveedor3', '2023-03-12', 'Almacén A')
# (339, 'Objeto339', 'Electrónica', 88.68, 44, 'Proveedor2', '2023-02-06', 'Almacén A')
# (340, 'Objeto340', 'Moda', 14.06, 64, 'Proveedor3', '2023-02-02', 'Almacén B')
# (341, 'Producto341', 'Deportes', 301.97, 96, 'Proveedor2', '2023-08-19', 'Almacén A')
# (342, 'Producto342', 'Hogar', 296.28, 52, 'Proveedor2', '2023-03-04', 'Almacén A')
# (343, 'Producto343', 'Moda', 350.39, 14, 'Proveedor3', '2023-04-09', 'Almacén C')
# (344, 'Objeto344', 'Hogar', 244.55, 62, 'Proveedor2', '2023-03-06', 'Almacén A')
# (345, 'Artículo345', 'Deportes', 455.66, 26, 'Proveedor3', '2023-02-05', 'Almacén B')
# (346, 'Artículo346', 'Jardín', 53.72, 79, 'Proveedor2', '2023-06-07', 'Almacén C')
# (347, 'Artículo347', 'Moda', 100.07, 100, 'Proveedor2', '2023-01-13', 'Almacén C')
# (348, 'Artículo348', 'Moda', 427.64, 7, 'Proveedor1', '2023-02-03', 'Almacén B')
# (349, 'Objeto349', 'Jardín', 393.63, 10, 'Proveedor1', '2023-10-18', 'Almacén A')
# (350, 'Objeto350', 'Jardín', 397, 40, 'Proveedor2', '2023-01-03', 'Almacén A')
# (351, 'Producto351', 'Electrónica', 184.58, 38, 'Proveedor1', '2023-05-12', 'Almacén C')
# (352, 'Objeto352', 'Moda', 38.62, 94, 'Proveedor3', '2023-04-08', 'Almacén B')
# (353, 'Objeto353', 'Jardín', 100.81, 1, 'Proveedor2', '2023-12-28', 'Almacén B')
# (354, 'Objeto354', 'Electrónica', 490.1, 23, 'Proveedor3', '2023-11-13', 'Almacén C')
# (355, 'Artículo355', 'Jardín', 337.82, 59, 'Proveedor2', '2023-09-07', 'Almacén C')
# (356, 'Producto356', 'Electrónica', 127.25, 21, 'Proveedor2', '2023-11-10', 'Almacén A')
# (357, 'Artículo357', 'Hogar', 224.74, 23, 'Proveedor2', '2023-01-09', 'Almacén A')
# (358, 'Objeto358', 'Deportes', 248.18, 40, 'Proveedor2', '2023-03-18', 'Almacén A')
# (359, 'Producto359', 'Deportes', 401.41, 57, 'Proveedor2', '2023-09-09', 'Almacén A')
# (360, 'Producto360', 'Moda', 487.06, 47, 'Proveedor2', '2023-03-05', 'Almacén C')
# (361, 'Objeto361', 'Moda', 230.1, 79, 'Proveedor2', '2023-10-27', 'Almacén A')
# (362, 'Objeto362', 'Electrónica', 296.18, 58, 'Proveedor1', '2023-02-05', 'Almacén A')
# (363, 'Producto363', 'Electrónica', 243.09, 7, 'Proveedor3', '2023-12-05', 'Almacén B')
# (364, 'Objeto364', 'Moda', 316.31, 42, 'Proveedor3', '2023-09-03', 'Almacén A')
# (365, 'Artículo365', 'Hogar', 208.26, 37, 'Proveedor1', '2023-08-22', 'Almacén C')
# (366, 'Producto366', 'Moda', 209.61, 79, 'Proveedor2', '2023-05-13', 'Almacén B')
# (367, 'Producto367', 'Jardín', 314.99, 40, 'Proveedor3', '2023-03-12', 'Almacén C')
# (368, 'Producto368', 'Jardín', 70.6, 21, 'Proveedor1', '2023-08-12', 'Almacén B')
# (369, 'Producto369', 'Jardín', 447.99, 99, 'Proveedor1', '2023-10-19', 'Almacén A')
# (370, 'Objeto370', 'Deportes', 359.99, 2, 'Proveedor1', '2023-11-27', 'Almacén B')
# (371, 'Producto371', 'Moda', 334.25, 21, 'Proveedor3', '2023-03-08', 'Almacén A')
# (372, 'Producto372', 'Moda', 125.03, 16, 'Proveedor2', '2023-06-10', 'Almacén C')
# (373, 'Objeto373', 'Hogar', 403.8, 40, 'Proveedor3', '2023-08-27', 'Almacén C')
# (374, 'Artículo374', 'Electrónica', 428.52, 18, 'Proveedor2', '2023-06-02', 'Almacén C')
# (375, 'Producto375', 'Hogar', 239.54, 56, 'Proveedor3', '2023-09-26', 'Almacén B')
# (376, 'Producto376', 'Deportes', 109.01, 33, 'Proveedor2', '2023-06-13', 'Almacén A')
# (377, 'Producto377', 'Jardín', 61.73, 49, 'Proveedor2', '2023-06-17', 'Almacén B')
# (378, 'Producto378', 'Jardín', 450.06, 52, 'Proveedor1', '2023-08-08', 'Almacén C')
# (379, 'Artículo379', 'Deportes', 389.63, 88, 'Proveedor2', '2023-02-08', 'Almacén B')
# (380, 'Objeto380', 'Jardín', 365.84, 59, 'Proveedor3', '2023-11-12', 'Almacén A')
# (381, 'Objeto381', 'Deportes', 41.45, 17, 'Proveedor3', '2023-07-03', 'Almacén B')
# (382, 'Producto382', 'Hogar', 266.62, 91, 'Proveedor2', '2023-12-23', 'Almacén C')
# (383, 'Artículo383', 'Deportes', 79.92, 30, 'Proveedor3', '2023-04-24', 'Almacén C')
# (384, 'Artículo384', 'Electrónica', 15.25, 56, 'Proveedor1', '2023-11-18', 'Almacén A')
# (385, 'Objeto385', 'Deportes', 412.01, 35, 'Proveedor1', '2023-03-25', 'Almacén A')
# (386, 'Artículo386', 'Moda', 403.47, 37, 'Proveedor1', '2023-04-01', 'Almacén B')
# (387, 'Producto387', 'Hogar', 138.14, 63, 'Proveedor2', '2023-11-14', 'Almacén A')
# (388, 'Objeto388', 'Electrónica', 450.39, 8, 'Proveedor1', '2023-03-17', 'Almacén C')
# (389, 'Artículo389', 'Hogar', 45.11, 47, 'Proveedor2', '2023-07-03', 'Almacén B')
# (390, 'Artículo390', 'Deportes', 87.87, 6, 'Proveedor2', '2023-11-17', 'Almacén A')
# (391, 'Producto391', 'Hogar', 221.52, 98, 'Proveedor2', '2023-02-12', 'Almacén A')
# (392, 'Artículo392', 'Electrónica', 71.9, 10, 'Proveedor2', '2023-09-26', 'Almacén B')
# (393, 'Objeto393', 'Hogar', 380.78, 96, 'Proveedor1', '2023-11-07', 'Almacén C')
# (394, 'Artículo394', 'Deportes', 113.18, 95, 'Proveedor3', '2023-01-05', 'Almacén A')
# (395, 'Producto395', 'Hogar', 97.78, 53, 'Proveedor3', '2023-10-18', 'Almacén C')
# (396, 'Artículo396', 'Hogar', 30.65, 23, 'Proveedor1', '2023-10-23', 'Almacén A')
# (397, 'Objeto397', 'Moda', 109.25, 16, 'Proveedor1', '2023-02-16', 'Almacén A')
# (398, 'Objeto398', 'Moda', 58.73, 60, 'Proveedor1', '2023-02-23', 'Almacén C')
# (399, 'Objeto399', 'Hogar', 290.87, 33, 'Proveedor2', '2023-11-25', 'Almacén C')
# (400, 'Producto400', 'Moda', 397.69, 26, 'Proveedor1', '2023-09-10', 'Almacén C')
# (401, 'Artículo401', 'Electrónica', 82.9, 26, 'Proveedor3', '2023-06-04', 'Almacén B')
# (402, 'Producto402', 'Hogar', 286.34, 4, 'Proveedor1', '2023-01-04', 'Almacén C')
# (403, 'Artículo403', 'Moda', 128.46, 88, 'Proveedor1', '2023-03-01', 'Almacén B')
# (404, 'Producto404', 'Electrónica', 90.46, 99, 'Proveedor1', '2023-12-08', 'Almacén A')
# (405, 'Artículo405', 'Moda', 151.13, 91, 'Proveedor2', '2023-09-12', 'Almacén A')
# (406, 'Producto406', 'Electrónica', 320.7, 8, 'Proveedor2', '2023-12-15', 'Almacén A')
# (407, 'Objeto407', 'Jardín', 421.41, 91, 'Proveedor2', '2023-10-18', 'Almacén A')
# (408, 'Artículo408', 'Electrónica', 431.22, 86, 'Proveedor1', '2023-08-21', 'Almacén A')
# (409, 'Artículo409', 'Electrónica', 50.83, 22, 'Proveedor2', '2023-01-15', 'Almacén C')
# (410, 'Producto410', 'Jardín', 231.84, 22, 'Proveedor2', '2023-01-16', 'Almacén B')
# (411, 'Objeto411', 'Moda', 389.14, 6, 'Proveedor3', '2023-08-11', 'Almacén C')
# (412, 'Artículo412', 'Moda', 228.79, 51, 'Proveedor1', '2023-01-11', 'Almacén C')
# (413, 'Objeto413', 'Electrónica', 457.59, 24, 'Proveedor3', '2023-08-05', 'Almacén A')
# (414, 'Artículo414', 'Electrónica', 349.84, 51, 'Proveedor2', '2023-06-15', 'Almacén B')
# (415, 'Objeto415', 'Moda', 321.88, 70, 'Proveedor3', '2023-04-21', 'Almacén C')
# (416, 'Producto416', 'Deportes', 54.75, 20, 'Proveedor2', '2023-03-16', 'Almacén B')
# (417, 'Producto417', 'Hogar', 88.38, 9, 'Proveedor3', '2023-04-06', 'Almacén C')
# (418, 'Artículo418', 'Moda', 300.89, 43, 'Proveedor1', '2023-11-15', 'Almacén C')
# (419, 'Objeto419', 'Moda', 233, 69, 'Proveedor1', '2023-07-02', 'Almacén C')
# (420, 'Objeto420', 'Moda', 316.71, 22, 'Proveedor1', '2023-08-05', 'Almacén C')
# (421, 'Artículo421', 'Hogar', 245.47, 39, 'Proveedor3', '2023-11-06', 'Almacén B')
# (422, 'Producto422', 'Moda', 229.27, 13, 'Proveedor2', '2023-11-18', 'Almacén C')
# (423, 'Producto423', 'Moda', 424.96, 8, 'Proveedor1', '2023-11-11', 'Almacén C')
# (424, 'Objeto424', 'Moda', 387.38, 77, 'Proveedor1', '2023-12-16', 'Almacén C')
# (425, 'Artículo425', 'Deportes', 424.32, 25, 'Proveedor2', '2023-09-15', 'Almacén B')
# (426, 'Artículo426', 'Hogar', 342.49, 25, 'Proveedor3', '2023-03-20', 'Almacén A')
# (427, 'Objeto427', 'Moda', 265.37, 20, 'Proveedor1', '2023-09-04', 'Almacén C')
# (428, 'Objeto428', 'Hogar', 474.12, 26, 'Proveedor2', '2023-11-10', 'Almacén B')
# (429, 'Objeto429', 'Deportes', 472.9, 97, 'Proveedor3', '2023-01-04', 'Almacén A')
# (430, 'Objeto430', 'Electrónica', 394.72, 43, 'Proveedor1', '2023-09-06', 'Almacén B')
# (431, 'Producto431', 'Jardín', 191.63, 3, 'Proveedor1', '2023-04-24', 'Almacén A')
# (432, 'Artículo432', 'Jardín', 384.69, 35, 'Proveedor2', '2023-12-28', 'Almacén B')
# (433, 'Objeto433', 'Moda', 474.26, 80, 'Proveedor3', '2023-07-17', 'Almacén B')
# (434, 'Artículo434', 'Jardín', 118.18, 97, 'Proveedor3', '2023-01-16', 'Almacén A')
# (435, 'Producto435', 'Electrónica', 293.68, 67, 'Proveedor3', '2023-11-04', 'Almacén C')
# (436, 'Artículo436', 'Jardín', 53.75, 19, 'Proveedor2', '2023-06-15', 'Almacén B')
# (437, 'Producto437', 'Electrónica', 387.55, 50, 'Proveedor1', '2023-03-01', 'Almacén C')
# (438, 'Artículo438', 'Moda', 143.93, 85, 'Proveedor1', '2023-04-27', 'Almacén C')
# (439, 'Objeto439', 'Moda', 157.28, 28, 'Proveedor1', '2023-01-12', 'Almacén C')
# (440, 'Producto440', 'Electrónica', 429.67, 34, 'Proveedor2', '2023-05-20', 'Almacén B')
# (441, 'Producto441', 'Electrónica', 214.46, 97, 'Proveedor3', '2023-10-04', 'Almacén B')
# (442, 'Objeto442', 'Electrónica', 107.51, 1, 'Proveedor2', '2023-01-13', 'Almacén C')
# (443, 'Artículo443', 'Hogar', 225.68, 42, 'Proveedor2', '2023-03-28', 'Almacén A')
# (444, 'Producto444', 'Deportes', 417.26, 5, 'Proveedor1', '2023-01-23', 'Almacén B')
# (445, 'Objeto445', 'Hogar', 228.25, 48, 'Proveedor2', '2023-12-22', 'Almacén C')
# (446, 'Objeto446', 'Hogar', 326.95, 96, 'Proveedor1', '2023-12-08', 'Almacén B')
# (447, 'Objeto447', 'Hogar', 452.31, 38, 'Proveedor1', '2023-04-12', 'Almacén A')
# (448, 'Producto448', 'Electrónica', 67.41, 59, 'Proveedor2', '2023-12-19', 'Almacén C')
# (449, 'Objeto449', 'Moda', 418.48, 62, 'Proveedor3', '2023-02-21', 'Almacén A')
# (450, 'Objeto450', 'Moda', 141.74, 35, 'Proveedor1', '2023-08-08', 'Almacén B')
# (451, 'Artículo451', 'Moda', 452.12, 47, 'Proveedor1', '2023-06-15', 'Almacén B')
# (452, 'Objeto452', 'Electrónica', 110.95, 59, 'Proveedor2', '2023-12-18', 'Almacén B')
# (453, 'Artículo453', 'Hogar', 462, 14, 'Proveedor2', '2023-04-25', 'Almacén A')
# (454, 'Objeto454', 'Electrónica', 144.27, 95, 'Proveedor3', '2023-11-10', 'Almacén B')
# (455, 'Artículo455', 'Deportes', 362.55, 92, 'Proveedor1', '2023-05-10', 'Almacén A')
# (456, 'Producto456', 'Hogar', 363.5, 19, 'Proveedor1', '2023-12-10', 'Almacén A')
# (457, 'Artículo457', 'Hogar', 97.06, 74, 'Proveedor1', '2023-06-27', 'Almacén C')
# (458, 'Objeto458', 'Hogar', 368.81, 40, 'Proveedor3', '2023-03-24', 'Almacén B')
# (459, 'Artículo459', 'Electrónica', 131.32, 2, 'Proveedor3', '2023-08-23', 'Almacén A')
# (460, 'Objeto460', 'Hogar', 319.65, 69, 'Proveedor2', '2023-08-16', 'Almacén C')
# (461, 'Objeto461', 'Jardín', 404.71, 59, 'Proveedor2', '2023-02-06', 'Almacén A')
# (462, 'Artículo462', 'Hogar', 326.09, 25, 'Proveedor3', '2023-05-09', 'Almacén B')
# (463, 'Producto463', 'Hogar', 309.44, 58, 'Proveedor2', '2023-01-05', 'Almacén B')
# (464, 'Objeto464', 'Jardín', 223.42, 51, 'Proveedor1', '2023-07-20', 'Almacén C')
# (465, 'Producto465', 'Deportes', 17.44, 99, 'Proveedor3', '2023-01-21', 'Almacén A')
# (466, 'Objeto466', 'Moda', 134.95, 65, 'Proveedor1', '2023-02-16', 'Almacén A')
# (467, 'Producto467', 'Deportes', 492.07, 36, 'Proveedor2', '2023-12-23', 'Almacén B')
# (468, 'Producto468', 'Deportes', 26.9, 51, 'Proveedor2', '2023-07-27', 'Almacén A')
# (469, 'Artículo469', 'Deportes', 142.44, 81, 'Proveedor2', '2023-09-13', 'Almacén C')
# (470, 'Producto470', 'Hogar', 266.92, 6, 'Proveedor3', '2023-07-24', 'Almacén A')
# (471, 'Artículo471', 'Jardín', 370.09, 37, 'Proveedor3', '2023-09-01', 'Almacén A')
# (472, 'Objeto472', 'Deportes', 463.94, 43, 'Proveedor3', '2023-03-02', 'Almacén B')
# (473, 'Producto473', 'Hogar', 75.7, 28, 'Proveedor2', '2023-03-14', 'Almacén B')
# (474, 'Producto474', 'Jardín', 496.07, 19, 'Proveedor1', '2023-01-14', 'Almacén B')
# (475, 'Artículo475', 'Deportes', 287.59, 18, 'Proveedor3', '2023-04-24', 'Almacén A')
# (476, 'Producto476', 'Deportes', 91.28, 4, 'Proveedor3', '2023-01-17', 'Almacén B')
# (477, 'Objeto477', 'Electrónica', 137.51, 1, 'Proveedor2', '2023-11-23', 'Almacén A')
# (478, 'Artículo478', 'Jardín', 440.3, 41, 'Proveedor3', '2023-01-22', 'Almacén B')
# (479, 'Producto479', 'Moda', 205.2, 23, 'Proveedor2', '2023-11-16', 'Almacén C')
# (480, 'Artículo480', 'Electrónica', 268.91, 15, 'Proveedor1', '2023-03-17', 'Almacén A')
# (481, 'Artículo481', 'Deportes', 340.38, 86, 'Proveedor3', '2023-09-11', 'Almacén A')
# (482, 'Artículo482', 'Electrónica', 335.03, 55, 'Proveedor3', '2023-02-07', 'Almacén C')
# (483, 'Producto483', 'Hogar', 197.15, 31, 'Proveedor2', '2023-10-12', 'Almacén B')
# (484, 'Artículo484', 'Hogar', 489.01, 53, 'Proveedor2', '2023-07-01', 'Almacén A')
# (485, 'Artículo485', 'Electrónica', 395.68, 18, 'Proveedor1', '2023-09-23', 'Almacén A')
# (486, 'Objeto486', 'Moda', 300.35, 41, 'Proveedor2', '2023-03-18', 'Almacén B')
# (487, 'Producto487', 'Moda', 354.53, 66, 'Proveedor3', '2023-06-28', 'Almacén C')
# (488, 'Producto488', 'Deportes', 302.74, 17, 'Proveedor1', '2023-10-25', 'Almacén A')
# (489, 'Objeto489', 'Electrónica', 293.74, 12, 'Proveedor3', '2023-07-13', 'Almacén A')
# (490, 'Producto490', 'Deportes', 481.83, 65, 'Proveedor2', '2023-06-11', 'Almacén C')
# (491, 'Artículo491', 'Hogar', 349.07, 22, 'Proveedor2', '2023-04-10', 'Almacén C')
# (492, 'Objeto492', 'Jardín', 357, 66, 'Proveedor1', '2023-03-22', 'Almacén C')
# (493, 'Objeto493', 'Hogar', 231.19, 43, 'Proveedor3', '2023-11-19', 'Almacén B')
# (494, 'Artículo494', 'Hogar', 139.05, 68, 'Proveedor1', '2023-01-09', 'Almacén A')
# (495, 'Artículo495', 'Jardín', 277.58, 43, 'Proveedor2', '2023-04-21', 'Almacén C')
# (496, 'Artículo496', 'Deportes', 270.84, 7, 'Proveedor1', '2023-11-10', 'Almacén C')
# (497, 'Producto497', 'Jardín', 234.49, 9, 'Proveedor1', '2023-03-06', 'Almacén C')
# (498, 'Producto498', 'Jardín', 51.61, 39, 'Proveedor3', '2023-04-18', 'Almacén A')
# (499, 'Objeto499', 'Electrónica', 25.44, 36, 'Proveedor1', '2023-01-24', 'Almacén C')
# (500, 'Producto500', 'Hogar', 246.53, 36, 'Proveedor3', '2023-10-27', 'Almacén B')
# (501, 'Artículo501', 'Jardín', 98.73, 57, 'Proveedor3', '2023-02-08', 'Almacén C')
# (502, 'Objeto502', 'Electrónica', 294.83, 89, 'Proveedor1', '2023-11-04', 'Almacén A')
# (503, 'Artículo503', 'Hogar', 372.75, 12, 'Proveedor1', '2023-09-23', 'Almacén A')
# (504, 'Producto504', 'Jardín', 109.8, 3, 'Proveedor2', '2023-06-15', 'Almacén B')
# (505, 'Artículo505', 'Moda', 73.41, 15, 'Proveedor1', '2023-04-07', 'Almacén C')
# (506, 'Artículo506', 'Moda', 298.3, 48, 'Proveedor3', '2023-03-27', 'Almacén A')
# (507, 'Artículo507', 'Electrónica', 289.43, 80, 'Proveedor3', '2023-10-03', 'Almacén B')
# (508, 'Objeto508', 'Electrónica', 168.5, 42, 'Proveedor1', '2023-09-09', 'Almacén C')
# (509, 'Producto509', 'Electrónica', 257.7, 68, 'Proveedor1', '2023-02-06', 'Almacén B')
# (510, 'Artículo510', 'Hogar', 186.74, 85, 'Proveedor1', '2023-01-14', 'Almacén A')
# (511, 'Objeto511', 'Moda', 299.32, 48, 'Proveedor3', '2023-07-23', 'Almacén B')
# (512, 'Producto512', 'Deportes', 279.52, 77, 'Proveedor1', '2023-09-20', 'Almacén B')
# (513, 'Objeto513', 'Deportes', 395.9, 99, 'Proveedor3', '2023-06-16', 'Almacén B')
# (514, 'Producto514', 'Moda', 415.53, 71, 'Proveedor1', '2023-11-12', 'Almacén A')
# (515, 'Artículo515', 'Electrónica', 295.65, 6, 'Proveedor3', '2023-11-08', 'Almacén C')
# (516, 'Producto516', 'Hogar', 372.14, 52, 'Proveedor2', '2023-08-28', 'Almacén B')
# (517, 'Producto517', 'Electrónica', 416.78, 32, 'Proveedor3', '2023-10-23', 'Almacén B')
# (518, 'Artículo518', 'Deportes', 431.48, 92, 'Proveedor2', '2023-05-22', 'Almacén C')
# (519, 'Objeto519', 'Deportes', 198.84, 63, 'Proveedor3', '2023-10-07', 'Almacén B')
# (520, 'Artículo520', 'Moda', 132.09, 66, 'Proveedor3', '2023-01-25', 'Almacén C')
# (521, 'Producto521', 'Hogar', 11.83, 14, 'Proveedor3', '2023-08-19', 'Almacén A')
# (522, 'Producto522', 'Jardín', 260.55, 70, 'Proveedor2', '2023-11-23', 'Almacén B')
# (523, 'Artículo523', 'Electrónica', 419.63, 41, 'Proveedor1', '2023-01-24', 'Almacén B')
# (524, 'Artículo524', 'Hogar', 441.51, 26, 'Proveedor2', '2023-04-07', 'Almacén C')
# (525, 'Producto525', 'Electrónica', 384.77, 71, 'Proveedor1', '2023-09-27', 'Almacén C')
# (526, 'Objeto526', 'Jardín', 127.92, 3, 'Proveedor2', '2023-05-05', 'Almacén B')
# (527, 'Artículo527', 'Electrónica', 162.92, 50, 'Proveedor3', '2023-10-21', 'Almacén A')
# (528, 'Producto528', 'Electrónica', 377.5, 44, 'Proveedor3', '2023-04-10', 'Almacén B')
# (529, 'Objeto529', 'Jardín', 94.83, 7, 'Proveedor3', '2023-06-21', 'Almacén A')
# (530, 'Objeto530', 'Hogar', 11.09, 1, 'Proveedor2', '2023-10-23', 'Almacén A')
# (531, 'Artículo531', 'Jardín', 236.91, 35, 'Proveedor2', '2023-12-19', 'Almacén C')
# (532, 'Producto532', 'Moda', 77.83, 27, 'Proveedor3', '2023-06-25', 'Almacén B')
# (533, 'Artículo533', 'Hogar', 61.85, 33, 'Proveedor1', '2023-05-13', 'Almacén C')
# (534, 'Artículo534', 'Deportes', 365.75, 23, 'Proveedor3', '2023-04-18', 'Almacén A')
# (535, 'Artículo535', 'Hogar', 237.42, 45, 'Proveedor1', '2023-08-23', 'Almacén C')
# (536, 'Producto536', 'Hogar', 374.37, 93, 'Proveedor1', '2023-07-18', 'Almacén C')
# (537, 'Producto537', 'Jardín', 92.27, 9, 'Proveedor2', '2023-02-18', 'Almacén C')
# (538, 'Objeto538', 'Jardín', 154.68, 24, 'Proveedor1', '2023-04-05', 'Almacén B')
# (539, 'Objeto539', 'Deportes', 40.63, 14, 'Proveedor1', '2023-03-12', 'Almacén C')
# (540, 'Producto540', 'Hogar', 298.52, 37, 'Proveedor3', '2023-03-01', 'Almacén B')
# (541, 'Objeto541', 'Electrónica', 384.08, 88, 'Proveedor3', '2023-12-06', 'Almacén B')
# (542, 'Objeto542', 'Jardín', 169.47, 77, 'Proveedor1', '2023-09-07', 'Almacén C')
# (543, 'Artículo543', 'Hogar', 166.38, 65, 'Proveedor1', '2023-09-09', 'Almacén C')
# (544, 'Objeto544', 'Moda', 218.55, 99, 'Proveedor2', '2023-07-26', 'Almacén A')
# (545, 'Producto545', 'Jardín', 117.49, 58, 'Proveedor1', '2023-11-23', 'Almacén B')
# (546, 'Artículo546', 'Hogar', 155.69, 12, 'Proveedor2', '2023-09-01', 'Almacén C')
# (547, 'Objeto547', 'Hogar', 224.19, 94, 'Proveedor1', '2023-06-01', 'Almacén C')
# (548, 'Artículo548', 'Hogar', 260, 66, 'Proveedor1', '2023-11-14', 'Almacén A')
# (549, 'Artículo549', 'Deportes', 288.21, 17, 'Proveedor2', '2023-01-04', 'Almacén A')
# (550, 'Artículo550', 'Electrónica', 394.04, 8, 'Proveedor2', '2023-01-23', 'Almacén A')
# (551, 'Artículo551', 'Moda', 83.26, 23, 'Proveedor2', '2023-03-15', 'Almacén A')
# (552, 'Artículo552', 'Deportes', 377.86, 68, 'Proveedor2', '2023-12-18', 'Almacén B')
# (553, 'Objeto553', 'Electrónica', 130.95, 25, 'Proveedor2', '2023-06-28', 'Almacén A')
# (554, 'Objeto554', 'Jardín', 271.65, 15, 'Proveedor3', '2023-09-12', 'Almacén B')
# (555, 'Objeto555', 'Jardín', 400.14, 55, 'Proveedor1', '2023-10-12', 'Almacén B')
# (556, 'Producto556', 'Electrónica', 361.99, 55, 'Proveedor1', '2023-07-24', 'Almacén B')
# (557, 'Artículo557', 'Deportes', 159.96, 16, 'Proveedor1', '2023-06-22', 'Almacén C')
# (558, 'Artículo558', 'Hogar', 485.9, 21, 'Proveedor2', '2023-08-09', 'Almacén A')
# (559, 'Objeto559', 'Moda', 192.92, 1, 'Proveedor2', '2023-01-01', 'Almacén B')
# (560, 'Artículo560', 'Deportes', 296.58, 28, 'Proveedor3', '2023-09-01', 'Almacén A')
# (561, 'Objeto561', 'Deportes', 263.75, 38, 'Proveedor2', '2023-01-11', 'Almacén C')
# (562, 'Artículo562', 'Jardín', 426.59, 77, 'Proveedor1', '2023-06-04', 'Almacén B')
# (563, 'Objeto563', 'Jardín', 392.63, 76, 'Proveedor3', '2023-12-07', 'Almacén C')
# (564, 'Objeto564', 'Electrónica', 26.82, 48, 'Proveedor3', '2023-04-02', 'Almacén C')
# (565, 'Objeto565', 'Deportes', 82.63, 68, 'Proveedor1', '2023-06-20', 'Almacén B')
# (566, 'Objeto566', 'Deportes', 142.07, 93, 'Proveedor2', '2023-06-13', 'Almacén C')
# (567, 'Objeto567', 'Deportes', 477.5, 71, 'Proveedor1', '2023-03-18', 'Almacén A')
# (568, 'Objeto568', 'Moda', 19.71, 46, 'Proveedor1', '2023-01-13', 'Almacén A')
# (569, 'Producto569', 'Moda', 331.44, 84, 'Proveedor1', '2023-07-09', 'Almacén C')
# (570, 'Artículo570', 'Hogar', 413.55, 29, 'Proveedor1', '2023-02-13', 'Almacén C')
# (571, 'Artículo571', 'Deportes', 380.49, 92, 'Proveedor1', '2023-01-24', 'Almacén B')
# (572, 'Producto572', 'Electrónica', 465, 78, 'Proveedor3', '2023-07-24', 'Almacén C')
# (573, 'Producto573', 'Deportes', 483.11, 63, 'Proveedor1', '2023-09-13', 'Almacén A')
# (574, 'Producto574', 'Deportes', 192.4, 60, 'Proveedor1', '2023-09-20', 'Almacén A')
# (575, 'Objeto575', 'Deportes', 490.69, 78, 'Proveedor2', '2023-03-10', 'Almacén A')
# (576, 'Objeto576', 'Hogar', 195.03, 1, 'Proveedor2', '2023-10-18', 'Almacén A')
# ...
# (9815, 'Artículo9815', 'Jardín', 13, 80, 'Proveedor1', '2023-07-27', 'Almacén A')
# (9816, 'Objeto9816', 'Electrónica', 369.17, 31, 'Proveedor2', '2023-06-08', 'Almacén C')
# (9817, 'Artículo9817', 'Hogar', 498.58, 53, 'Proveedor1', '2023-04-01', 'Almacén C')
# (9818, 'Producto9818', 'Electrónica', 229.44, 92, 'Proveedor3', '2023-12-24', 'Almacén A')
# (9819, 'Producto9819', 'Electrónica', 413.85, 57, 'Proveedor3', '2023-08-23', 'Almacén A')
# (9820, 'Producto9820', 'Moda', 412.94, 23, 'Proveedor3', '2023-09-11', 'Almacén B')
# (9821, 'Objeto9821', 'Jardín', 184.61, 25, 'Proveedor2', '2023-02-17', 'Almacén A')
# (9822, 'Objeto9822', 'Electrónica', 83.85, 68, 'Proveedor3', '2023-05-01', 'Almacén C')
# (9823, 'Objeto9823', 'Hogar', 112.89, 62, 'Proveedor2', '2023-11-27', 'Almacén C')
# (9824, 'Producto9824', 'Jardín', 195.32, 16, 'Proveedor3', '2023-11-02', 'Almacén B')
# (9825, 'Objeto9825', 'Hogar', 108.89, 42, 'Proveedor1', '2023-08-14', 'Almacén B')
# (9826, 'Producto9826', 'Moda', 32.72, 38, 'Proveedor3', '2023-06-21', 'Almacén B')
# (9827, 'Objeto9827', 'Electrónica', 320.01, 36, 'Proveedor1', '2023-07-22', 'Almacén A')
# (9828, 'Artículo9828', 'Moda', 305.48, 11, 'Proveedor2', '2023-08-28', 'Almacén B')
# (9829, 'Objeto9829', 'Deportes', 153.38, 89, 'Proveedor2', '2023-06-22', 'Almacén C')
# (9830, 'Artículo9830', 'Electrónica', 290.34, 80, 'Proveedor3', '2023-01-03', 'Almacén A')
# (9831, 'Objeto9831', 'Deportes', 19.24, 19, 'Proveedor3', '2023-12-20', 'Almacén A')
# (9832, 'Artículo9832', 'Electrónica', 210.25, 13, 'Proveedor3', '2023-02-08', 'Almacén B')
# (9833, 'Objeto9833', 'Jardín', 154.95, 35, 'Proveedor1', '2023-05-06', 'Almacén A')
# (9834, 'Objeto9834', 'Jardín', 374.1, 94, 'Proveedor3', '2023-11-23', 'Almacén B')
# (9835, 'Artículo9835', 'Moda', 236.62, 3, 'Proveedor1', '2023-12-09', 'Almacén B')
# (9836, 'Producto9836', 'Jardín', 136.6, 48, 'Proveedor3', '2023-01-18', 'Almacén B')
# (9837, 'Artículo9837', 'Moda', 28.96, 77, 'Proveedor2', '2023-09-23', 'Almacén B')
# (9838, 'Producto9838', 'Electrónica', 14.1, 95, 'Proveedor1', '2023-03-06', 'Almacén C')
# (9839, 'Objeto9839', 'Jardín', 375.7, 50, 'Proveedor2', '2023-11-15', 'Almacén C')
# (9840, 'Producto9840', 'Hogar', 486.04, 45, 'Proveedor1', '2023-10-08', 'Almacén C')
# (9841, 'Objeto9841', 'Moda', 499.98, 79, 'Proveedor1', '2023-06-17', 'Almacén B')
# (9842, 'Producto9842', 'Deportes', 327.06, 6, 'Proveedor3', '2023-03-26', 'Almacén B')
# (9843, 'Artículo9843', 'Hogar', 463.88, 30, 'Proveedor3', '2023-12-23', 'Almacén A')
# (9844, 'Producto9844', 'Deportes', 422.07, 15, 'Proveedor3', '2023-07-06', 'Almacén B')
# (9845, 'Producto9845', 'Electrónica', 232.35, 1, 'Proveedor2', '2023-04-26', 'Almacén B')
# (9846, 'Artículo9846', 'Electrónica', 160.38, 93, 'Proveedor1', '2023-12-20', 'Almacén A')
# (9847, 'Artículo9847', 'Deportes', 211.26, 62, 'Proveedor2', '2023-08-25', 'Almacén B')
# (9848, 'Artículo9848', 'Moda', 193.63, 69, 'Proveedor1', '2023-03-15', 'Almacén C')
# (9849, 'Artículo9849', 'Jardín', 310.69, 69, 'Proveedor1', '2023-11-06', 'Almacén B')
# (9850, 'Producto9850', 'Moda', 464.15, 22, 'Proveedor1', '2023-11-28', 'Almacén C')
# (9851, 'Artículo9851', 'Moda', 83.01, 43, 'Proveedor3', '2023-05-09', 'Almacén A')
# (9852, 'Producto9852', 'Electrónica', 474.76, 15, 'Proveedor3', '2023-01-17', 'Almacén C')
# (9853, 'Producto9853', 'Jardín', 26.56, 82, 'Proveedor1', '2023-03-24', 'Almacén B')
# (9854, 'Artículo9854', 'Hogar', 452.21, 68, 'Proveedor3', '2023-03-15', 'Almacén A')
# (9855, 'Producto9855', 'Hogar', 200.92, 76, 'Proveedor3', '2023-01-04', 'Almacén B')
# (9856, 'Artículo9856', 'Moda', 149.88, 15, 'Proveedor1', '2023-12-10', 'Almacén B')
# (9857, 'Objeto9857', 'Jardín', 269.63, 37, 'Proveedor1', '2023-11-16', 'Almacén B')
# (9858, 'Artículo9858', 'Deportes', 169.24, 59, 'Proveedor1', '2023-01-27', 'Almacén B')
# (9859, 'Artículo9859', 'Hogar', 315.25, 32, 'Proveedor1', '2023-03-05', 'Almacén B')
# (9860, 'Artículo9860', 'Deportes', 415.28, 76, 'Proveedor2', '2023-01-02', 'Almacén A')
# (9861, 'Objeto9861', 'Moda', 96.4, 62, 'Proveedor3', '2023-06-27', 'Almacén C')
# (9862, 'Producto9862', 'Moda', 397.69, 43, 'Proveedor3', '2023-06-10', 'Almacén C')
# (9863, 'Artículo9863', 'Jardín', 400.02, 81, 'Proveedor2', '2023-07-15', 'Almacén C')
# (9864, 'Artículo9864', 'Electrónica', 137.56, 93, 'Proveedor3', '2023-01-12', 'Almacén B')
# (9865, 'Objeto9865', 'Electrónica', 434.89, 49, 'Proveedor1', '2023-09-19', 'Almacén C')
# (9866, 'Producto9866', 'Moda', 90.65, 73, 'Proveedor3', '2023-09-06', 'Almacén C')
# (9867, 'Objeto9867', 'Moda', 20.29, 20, 'Proveedor2', '2023-05-06', 'Almacén B')
# (9868, 'Artículo9868', 'Jardín', 27.03, 94, 'Proveedor1', '2023-05-04', 'Almacén B')
# (9869, 'Artículo9869', 'Moda', 145.35, 24, 'Proveedor3', '2023-02-17', 'Almacén B')
# (9870, 'Producto9870', 'Deportes', 364.72, 32, 'Proveedor1', '2023-09-26', 'Almacén B')
# (9871, 'Artículo9871', 'Hogar', 122.68, 88, 'Proveedor2', '2023-12-08', 'Almacén C')
# (9872, 'Objeto9872', 'Electrónica', 466.71, 32, 'Proveedor2', '2023-06-28', 'Almacén A')
# (9873, 'Producto9873', 'Moda', 111.3, 94, 'Proveedor3', '2023-08-19', 'Almacén C')
# (9874, 'Artículo9874', 'Deportes', 301.84, 14, 'Proveedor1', '2023-08-15', 'Almacén A')
# (9875, 'Objeto9875', 'Hogar', 347.31, 26, 'Proveedor1', '2023-02-06', 'Almacén A')
# (9876, 'Artículo9876', 'Moda', 317.01, 50, 'Proveedor2', '2023-08-20', 'Almacén C')
# (9877, 'Producto9877', 'Hogar', 379.65, 42, 'Proveedor2', '2023-01-11', 'Almacén C')
# (9878, 'Objeto9878', 'Deportes', 452.44, 92, 'Proveedor2', '2023-04-27', 'Almacén B')
# (9879, 'Objeto9879', 'Hogar', 350.93, 17, 'Proveedor1', '2023-08-03', 'Almacén C')
# (9880, 'Objeto9880', 'Jardín', 193.23, 87, 'Proveedor2', '2023-08-10', 'Almacén A')
# (9881, 'Producto9881', 'Electrónica', 159.93, 80, 'Proveedor1', '2023-04-11', 'Almacén C')
# (9882, 'Producto9882', 'Electrónica', 336.23, 85, 'Proveedor3', '2023-04-15', 'Almacén A')
# (9883, 'Objeto9883', 'Moda', 56.61, 66, 'Proveedor1', '2023-05-21', 'Almacén C')
# (9884, 'Objeto9884', 'Moda', 455.25, 25, 'Proveedor1', '2023-06-20', 'Almacén B')
# (9885, 'Objeto9885', 'Deportes', 13.53, 87, 'Proveedor2', '2023-04-24', 'Almacén A')
# (9886, 'Objeto9886', 'Electrónica', 53.99, 53, 'Proveedor1', '2023-11-02', 'Almacén C')
# (9887, 'Producto9887', 'Deportes', 63.65, 20, 'Proveedor1', '2023-01-11', 'Almacén C')
# (9888, 'Producto9888', 'Jardín', 262.32, 49, 'Proveedor2', '2023-03-11', 'Almacén B')
# (9889, 'Artículo9889', 'Hogar', 18.01, 86, 'Proveedor3', '2023-04-09', 'Almacén A')
# (9890, 'Artículo9890', 'Moda', 249.45, 31, 'Proveedor1', '2023-09-07', 'Almacén A')
# (9891, 'Objeto9891', 'Jardín', 476.33, 32, 'Proveedor1', '2023-10-02', 'Almacén A')
# (9892, 'Objeto9892', 'Jardín', 362.22, 40, 'Proveedor3', '2023-09-27', 'Almacén C')
# (9893, 'Artículo9893', 'Electrónica', 317.2, 90, 'Proveedor1', '2023-12-20', 'Almacén C')
# (9894, 'Producto9894', 'Deportes', 136.1, 32, 'Proveedor3', '2023-12-27', 'Almacén C')
# (9895, 'Producto9895', 'Deportes', 478.19, 76, 'Proveedor1', '2023-12-13', 'Almacén C')
# (9896, 'Artículo9896', 'Electrónica', 37.08, 71, 'Proveedor1', '2023-05-21', 'Almacén C')
# (9897, 'Artículo9897', 'Jardín', 46.83, 55, 'Proveedor2', '2023-08-12', 'Almacén C')
# (9898, 'Artículo9898', 'Electrónica', 58.05, 65, 'Proveedor1', '2023-05-13', 'Almacén C')
# (9899, 'Objeto9899', 'Jardín', 87.52, 72, 'Proveedor1', '2023-12-28', 'Almacén A')
# (9900, 'Producto9900', 'Hogar', 29.9, 33, 'Proveedor1', '2023-06-28', 'Almacén A')
# (9901, 'Objeto9901', 'Electrónica', 474.56, 85, 'Proveedor1', '2023-06-04', 'Almacén C')
# (9902, 'Artículo9902', 'Deportes', 476.37, 8, 'Proveedor2', '2023-05-19', 'Almacén C')
# (9903, 'Producto9903', 'Hogar', 330.36, 37, 'Proveedor3', '2023-10-25', 'Almacén A')
# (9904, 'Artículo9904', 'Deportes', 119.79, 66, 'Proveedor3', '2023-07-02', 'Almacén A')
# (9905, 'Producto9905', 'Moda', 365.52, 66, 'Proveedor3', '2023-10-06', 'Almacén A')
# (9906, 'Producto9906', 'Deportes', 294.93, 11, 'Proveedor3', '2023-11-27', 'Almacén C')
# (9907, 'Artículo9907', 'Moda', 32.23, 95, 'Proveedor2', '2023-07-06', 'Almacén C')
# (9908, 'Artículo9908', 'Deportes', 436.98, 63, 'Proveedor1', '2023-03-24', 'Almacén B')
# (9909, 'Producto9909', 'Jardín', 294.91, 8, 'Proveedor3', '2023-09-24', 'Almacén B')
# (9910, 'Producto9910', 'Deportes', 421.41, 53, 'Proveedor3', '2023-08-13', 'Almacén A')
# (9911, 'Artículo9911', 'Hogar', 286.27, 14, 'Proveedor3', '2023-12-25', 'Almacén B')
# (9912, 'Objeto9912', 'Electrónica', 39.23, 66, 'Proveedor1', '2023-08-02', 'Almacén B')
# (9913, 'Producto9913', 'Moda', 255.09, 58, 'Proveedor3', '2023-11-28', 'Almacén A')
# (9914, 'Producto9914', 'Moda', 198.42, 25, 'Proveedor1', '2023-06-20', 'Almacén B')
# (9915, 'Producto9915', 'Electrónica', 229.54, 76, 'Proveedor2', '2023-04-28', 'Almacén A')
# (9916, 'Producto9916', 'Deportes', 68.84, 86, 'Proveedor1', '2023-06-01', 'Almacén A')
# (9917, 'Objeto9917', 'Hogar', 25.23, 18, 'Proveedor3', '2023-11-26', 'Almacén B')
# (9918, 'Artículo9918', 'Hogar', 409.21, 70, 'Proveedor1', '2023-06-27', 'Almacén C')
# (9919, 'Artículo9919', 'Moda', 10.98, 24, 'Proveedor2', '2023-08-06', 'Almacén A')
# (9920, 'Artículo9920', 'Moda', 442.66, 52, 'Proveedor3', '2023-05-23', 'Almacén C')
# (9921, 'Artículo9921', 'Hogar', 138.78, 6, 'Proveedor3', '2023-09-26', 'Almacén B')
# (9922, 'Artículo9922', 'Electrónica', 380.02, 5, 'Proveedor2', '2023-12-26', 'Almacén B')
# (9923, 'Producto9923', 'Moda', 474.91, 48, 'Proveedor3', '2023-04-15', 'Almacén C')
# (9924, 'Artículo9924', 'Electrónica', 495.57, 81, 'Proveedor3', '2023-04-18', 'Almacén A')
# (9925, 'Artículo9925', 'Hogar', 259.97, 94, 'Proveedor2', '2023-07-20', 'Almacén B')
# (9926, 'Artículo9926', 'Moda', 246.37, 22, 'Proveedor2', '2023-04-14', 'Almacén B')
# (9927, 'Objeto9927', 'Moda', 391.66, 84, 'Proveedor1', '2023-10-01', 'Almacén B')
# (9928, 'Producto9928', 'Moda', 14.47, 44, 'Proveedor2', '2023-10-04', 'Almacén B')
# (9929, 'Producto9929', 'Electrónica', 184.08, 26, 'Proveedor3', '2023-03-20', 'Almacén B')
# (9930, 'Artículo9930', 'Moda', 496.7, 27, 'Proveedor3', '2023-07-20', 'Almacén A')
# (9931, 'Producto9931', 'Jardín', 337.36, 90, 'Proveedor3', '2023-02-03', 'Almacén C')
# (9932, 'Artículo9932', 'Electrónica', 338.98, 84, 'Proveedor2', '2023-02-02', 'Almacén A')
# (9933, 'Artículo9933', 'Moda', 304.38, 19, 'Proveedor3', '2023-11-01', 'Almacén B')
# (9934, 'Objeto9934', 'Hogar', 131.51, 71, 'Proveedor2', '2023-02-17', 'Almacén A')
# (9935, 'Producto9935', 'Electrónica', 161.21, 84, 'Proveedor1', '2023-08-20', 'Almacén A')
# (9936, 'Artículo9936', 'Electrónica', 163.27, 86, 'Proveedor1', '2023-03-15', 'Almacén B')
# (9937, 'Artículo9937', 'Hogar', 218.4, 78, 'Proveedor3', '2023-12-19', 'Almacén C')
# (9938, 'Artículo9938', 'Moda', 294.75, 27, 'Proveedor2', '2023-08-26', 'Almacén C')
# (9939, 'Objeto9939', 'Moda', 14.89, 95, 'Proveedor1', '2023-06-11', 'Almacén C')
# (9940, 'Objeto9940', 'Jardín', 344.92, 92, 'Proveedor1', '2023-02-12', 'Almacén C')
# (9941, 'Artículo9941', 'Deportes', 211.75, 39, 'Proveedor1', '2023-06-03', 'Almacén B')
# (9942, 'Artículo9942', 'Moda', 379.65, 30, 'Proveedor3', '2023-04-28', 'Almacén B')
# (9943, 'Artículo9943', 'Hogar', 353.93, 42, 'Proveedor2', '2023-08-09', 'Almacén C')
# (9944, 'Artículo9944', 'Electrónica', 24.71, 67, 'Proveedor3', '2023-06-18', 'Almacén B')
# (9945, 'Objeto9945', 'Jardín', 91.87, 54, 'Proveedor2', '2023-05-04', 'Almacén C')
# (9946, 'Objeto9946', 'Jardín', 416.45, 6, 'Proveedor3', '2023-07-20', 'Almacén C')
# (9947, 'Producto9947', 'Moda', 377.52, 84, 'Proveedor3', '2023-07-15', 'Almacén A')
# (9948, 'Producto9948', 'Moda', 97.93, 3, 'Proveedor3', '2023-03-05', 'Almacén A')
# (9949, 'Objeto9949', 'Jardín', 133.22, 66, 'Proveedor3', '2023-08-15', 'Almacén A')
# (9950, 'Producto9950', 'Hogar', 486.38, 66, 'Proveedor3', '2023-03-14', 'Almacén C')
# (9951, 'Producto9951', 'Jardín', 226.03, 21, 'Proveedor3', '2023-05-28', 'Almacén B')
# (9952, 'Artículo9952', 'Hogar', 88.56, 36, 'Proveedor2', '2023-06-28', 'Almacén B')
# (9953, 'Artículo9953', 'Electrónica', 391.93, 4, 'Proveedor2', '2023-01-19', 'Almacén A')
# (9954, 'Objeto9954', 'Electrónica', 371.62, 28, 'Proveedor1', '2023-03-07', 'Almacén B')
# (9955, 'Artículo9955', 'Electrónica', 446.64, 87, 'Proveedor3', '2023-06-13', 'Almacén A')
# (9956, 'Objeto9956', 'Deportes', 58.74, 100, 'Proveedor3', '2023-09-03', 'Almacén B')
# (9957, 'Objeto9957', 'Jardín', 381.33, 67, 'Proveedor3', '2023-12-11', 'Almacén B')
# (9958, 'Producto9958', 'Hogar', 132.64, 53, 'Proveedor1', '2023-05-24', 'Almacén B')
# (9959, 'Producto9959', 'Hogar', 238.99, 75, 'Proveedor2', '2023-09-18', 'Almacén B')
# (9960, 'Artículo9960', 'Moda', 219.28, 44, 'Proveedor1', '2023-08-19', 'Almacén A')
# (9961, 'Objeto9961', 'Jardín', 156.48, 8, 'Proveedor1', '2023-11-02', 'Almacén C')
# (9962, 'Producto9962', 'Electrónica', 87.52, 13, 'Proveedor3', '2023-05-19', 'Almacén B')
# (9963, 'Producto9963', 'Jardín', 94.69, 21, 'Proveedor3', '2023-08-27', 'Almacén B')
# (9964, 'Objeto9964', 'Jardín', 115.73, 5, 'Proveedor2', '2023-01-06', 'Almacén C')
# (9965, 'Producto9965', 'Jardín', 377.55, 21, 'Proveedor2', '2023-03-11', 'Almacén B')
# (9966, 'Producto9966', 'Hogar', 273.3, 30, 'Proveedor2', '2023-10-22', 'Almacén C')
# (9967, 'Objeto9967', 'Jardín', 400.38, 66, 'Proveedor3', '2023-02-28', 'Almacén B')
# (9968, 'Artículo9968', 'Deportes', 415.54, 53, 'Proveedor3', '2023-01-02', 'Almacén A')
# (9969, 'Producto9969', 'Hogar', 117.1, 47, 'Proveedor3', '2023-07-14', 'Almacén C')
# (9970, 'Artículo9970', 'Jardín', 329.82, 67, 'Proveedor1', '2023-09-05', 'Almacén B')
# (9971, 'Artículo9971', 'Electrónica', 489.59, 24, 'Proveedor2', '2023-03-25', 'Almacén C')
# (9972, 'Producto9972', 'Electrónica', 495.55, 11, 'Proveedor3', '2023-03-07', 'Almacén C')
# (9973, 'Objeto9973', 'Deportes', 205.98, 76, 'Proveedor2', '2023-06-24', 'Almacén C')
# (9974, 'Producto9974', 'Deportes', 137.61, 88, 'Proveedor2', '2023-07-18', 'Almacén B')
# (9975, 'Producto9975', 'Moda', 416.75, 23, 'Proveedor3', '2023-10-22', 'Almacén B')
# (9976, 'Artículo9976', 'Hogar', 210.95, 3, 'Proveedor3', '2023-03-18', 'Almacén B')
# (9977, 'Producto9977', 'Electrónica', 85.04, 38, 'Proveedor3', '2023-06-23', 'Almacén B')
# (9978, 'Artículo9978', 'Moda', 163.58, 27, 'Proveedor2', '2023-04-26', 'Almacén B')
# (9979, 'Objeto9979', 'Hogar', 299.04, 69, 'Proveedor2', '2023-06-27', 'Almacén A')
# (9980, 'Artículo9980', 'Electrónica', 186.77, 47, 'Proveedor3', '2023-08-24', 'Almacén B')
# (9981, 'Producto9981', 'Jardín', 307.82, 71, 'Proveedor1', '2023-12-28', 'Almacén A')
# (9982, 'Artículo9982', 'Deportes', 18.95, 35, 'Proveedor1', '2023-04-13', 'Almacén A')
# (9983, 'Objeto9983', 'Moda', 374.71, 2, 'Proveedor1', '2023-11-06', 'Almacén A')
# (9984, 'Objeto9984', 'Deportes', 45.38, 51, 'Proveedor1', '2023-07-25', 'Almacén C')
# (9985, 'Objeto9985', 'Moda', 350.06, 47, 'Proveedor2', '2023-11-02', 'Almacén B')
# (9986, 'Objeto9986', 'Hogar', 219.33, 25, 'Proveedor3', '2023-04-24', 'Almacén A')
# (9987, 'Objeto9987', 'Electrónica', 154.41, 91, 'Proveedor2', '2023-02-28', 'Almacén A')
# (9988, 'Producto9988', 'Moda', 54.35, 58, 'Proveedor2', '2023-03-23', 'Almacén C')
# (9989, 'Artículo9989', 'Jardín', 50.09, 26, 'Proveedor2', '2023-05-09', 'Almacén C')
# (9990, 'Producto9990', 'Deportes', 241.17, 43, 'Proveedor3', '2023-03-22', 'Almacén A')
# (9991, 'Producto9991', 'Electrónica', 441.55, 25, 'Proveedor1', '2023-08-25', 'Almacén C')
# (9992, 'Producto9992', 'Jardín', 255.28, 37, 'Proveedor2', '2023-02-18', 'Almacén A')
# (9993, 'Artículo9993', 'Hogar', 425.13, 71, 'Proveedor1', '2023-12-04', 'Almacén A')
# (9994, 'Artículo9994', 'Hogar', 381.03, 37, 'Proveedor1', '2023-05-13', 'Almacén B')
# (9995, 'Artículo9995', 'Electrónica', 78.37, 72, 'Proveedor2', '2023-12-09', 'Almacén A')
# (9996, 'Producto9996', 'Deportes', 365.65, 36, 'Proveedor2', '2023-12-26', 'Almacén A')
# (9997, 'Artículo9997', 'Deportes', 132.24, 38, 'Proveedor3', '2023-01-26', 'Almacén B')
# (9998, 'Producto9998', 'Hogar', 128.43, 58, 'Proveedor3', '2023-05-12', 'Almacén C')
# (9999, 'Artículo9999', 'Hogar', 252.66, 45, 'Proveedor2', '2023-11-28', 'Almacén A')
# (10000, 'Producto10000', 'Hogar', 40.69, 68, 'Proveedor2', '2023-03-19', 'Almacén B')

# %% [markdown]
# ## Realizar consulta y transferir a dataframe

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Realizar la consulta y cargar los resultados en un DataFrame
query = "SELECT * FROM inventario WHERE precio > 450"
df_productos = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print(df_productos)

# Cerrar la conexión
conn.close()
# Out:
#        id        nombre    categoria  precio  cantidad   proveedor  \
# 0       4     Artículo4         Moda  497.15         7  Proveedor2
# 1      33    Producto33         Moda  493.92        46  Proveedor3
# 2      51      Objeto51        Hogar  475.95        70  Proveedor2
# 3      81    Artículo81       Jardín  480.18        64  Proveedor3
# 4      89      Objeto89        Hogar  467.15        48  Proveedor3
# ..    ...           ...          ...     ...       ...         ...
# 984  9924  Artículo9924  Electrónica  495.57        81  Proveedor3
# 985  9930  Artículo9930         Moda  496.70        27  Proveedor3
# 986  9950  Producto9950        Hogar  486.38        66  Proveedor3
# 987  9971  Artículo9971  Electrónica  489.59        24  Proveedor2
# 988  9972  Producto9972  Electrónica  495.55        11  Proveedor3
#
#     fecha_ingreso  ubicacion
# 0      2023-04-07  Almacén C
# 1      2023-04-12  Almacén C
# 2      2023-04-07  Almacén B
# 3      2023-05-25  Almacén A
# 4      2023-10-18  Almacén B
# ..            ...        ...
# 984    2023-04-18  Almacén A
# 985    2023-07-20  Almacén A
# 986    2023-03-14  Almacén C
# 987    2023-03-25  Almacén C
# 988    2023-03-07  Almacén C
#
# [989 rows x 8 columns]

# %%
df_productos.head()
# Out:
#    id      nombre categoria  precio  cantidad   proveedor fecha_ingreso  \
# 0   4   Artículo4      Moda  497.15         7  Proveedor2    2023-04-07
# 1  33  Producto33      Moda  493.92        46  Proveedor3    2023-04-12
# 2  51    Objeto51     Hogar  475.95        70  Proveedor2    2023-04-07
# 3  81  Artículo81    Jardín  480.18        64  Proveedor3    2023-05-25
# 4  89    Objeto89     Hogar  467.15        48  Proveedor3    2023-10-18
#
#    ubicacion
# 0  Almacén C
# 1  Almacén C
# 2  Almacén B
# 3  Almacén A
# 4  Almacén B

# %% [markdown]
# ## Nueva consulta

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Realizar la consulta y cargar los resultados en un DataFrame
query = "SELECT * FROM inventario WHERE precio > 450 AND cantidad > 25"
df_productos = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print(df_productos)


# Cerrar la conexión
conn.close()
# Out:
#        id        nombre    categoria  precio  cantidad   proveedor  \
# 0      33    Producto33         Moda  493.92        46  Proveedor3
# 1      51      Objeto51        Hogar  475.95        70  Proveedor2
# 2      81    Artículo81       Jardín  480.18        64  Proveedor3
# 3      89      Objeto89        Hogar  467.15        48  Proveedor3
# 4     109     Objeto109        Hogar  479.75        93  Proveedor3
# ..    ...           ...          ...     ...       ...         ...
# 728  9901    Objeto9901  Electrónica  474.56        85  Proveedor1
# 729  9923  Producto9923         Moda  474.91        48  Proveedor3
# 730  9924  Artículo9924  Electrónica  495.57        81  Proveedor3
# 731  9930  Artículo9930         Moda  496.70        27  Proveedor3
# 732  9950  Producto9950        Hogar  486.38        66  Proveedor3
#
#     fecha_ingreso  ubicacion
# 0      2023-04-12  Almacén C
# 1      2023-04-07  Almacén B
# 2      2023-05-25  Almacén A
# 3      2023-10-18  Almacén B
# 4      2023-09-27  Almacén C
# ..            ...        ...
# 728    2023-06-04  Almacén C
# 729    2023-04-15  Almacén C
# 730    2023-04-18  Almacén A
# 731    2023-07-20  Almacén A
# 732    2023-03-14  Almacén C
#
# [733 rows x 8 columns]

# %% [markdown]
# ## Insertar nuevo producto

# %%
# Datos del nuevo producto
nuevo_producto = (
    None,  # SQLite genera un nuevo id automáticamente si la columna es autoincrement
    'NuevoProducto123',
    'Electrónica',
    249.99,
    20,
    'ProveedorX',
    '2024-04-16',
    'Almacén D'
)

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Insersión de nuevo producto
c.execute('INSERT INTO inventario VALUES (?, ?, ?, ?, ?, ?, ?, ?)', nuevo_producto)

# Guardar (commit) los cambios y cerrar conexión con la DB
conn.commit()
conn.close()

# %% [markdown]
# ## Insertar nuevo producto desde Excel

# %% [markdown]
# ### Crear tabla excel de nuevos productos

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

np.random.seed(0)
num_prods = 5000

# Productos nuevos
nombres = ['Producto' + str(i) for i in range(num_prods)]
categorias = np.random.choice(['Electrónica', 'Hogar', 'Jardín', 'Moda', 'Deportes'], num_prods)
precios = np.round(np.random.uniform(10.0, 500.0, num_prods), 2)
cantidades = np.random.randint(1, 100, num_prods)
proveedores = np.random.choice(['Proveedor1', 'Proveedor2', 'Proveedor3'], num_prods)
fechas = [datetime.today() - timedelta(days=np.random.randint(0, 365)) for _ in range(num_prods)]
ubicaciones = np.random.choice(['Almacén A', 'Almacén B', 'Almacén C'], num_prods)

# DataFrame
df = pd.DataFrame({
    'Nombre': nombres,
    'Categoría': categorias,
    'Precio': precios,
    'Cantidad': cantidades,
    'Proveedor': proveedores,
    'Fecha de Ingreso': pd.to_datetime(fechas),
    'Ubicación': ubicaciones
})

print(df.head())

# Guardar el DataFrame en un archivo Excel
df.to_excel('nuevos_productos_inventario.xlsx', index=False)
# Out:
#       Nombre    Categoría  Precio  Cantidad   Proveedor  \
# 0  Producto0     Deportes  489.97        77  Proveedor1
# 1  Producto1  Electrónica  347.86        78  Proveedor3
# 2  Producto2         Moda   10.40        93  Proveedor2
# 3  Producto3         Moda  402.25        51  Proveedor3
# 4  Producto4         Moda  445.18        50  Proveedor1
#
#             Fecha de Ingreso  Ubicación
# 0 2025-06-17 00:55:47.642598  Almacén B
# 1 2025-03-22 00:55:47.642652  Almacén C
# 2 2024-12-28 00:55:47.642665  Almacén B
# 3 2025-08-25 00:55:47.642675  Almacén A
# 4 2024-12-11 00:55:47.642682  Almacén A

# %% [markdown]
# ### Agregar datos de tabla excel al inventario

# %%
import pandas as pd

# Leer archivo Excel
ruta_archivo = '/content/nuevos_productos_inventario.xlsx'
df = pd.read_excel(ruta_archivo)

# Verificación de formatos (tipo de dato)
# Precio a float
if df['Precio'].dtype != 'float':
    df['Precio'] = df['Precio'].astype(float)

# Fecha de Ingreso a datetime
if df['Fecha de Ingreso'].dtype != 'datetime64[ns]':
    df['Fecha de Ingreso'] = pd.to_datetime(df['Fecha de Ingreso'], errors='coerce')

# Verificar y corregir fechas no válidas, usando la fecha de hoy
df['Fecha de Ingreso'].fillna(pd.Timestamp.today(), inplace=True)

df.head()
# Out:
# /tmp/ipython-input-1041989223.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fecha de Ingreso'].fillna(pd.Timestamp.today(), inplace=True)
#       Nombre    Categoría  Precio  Cantidad   Proveedor  \
# 0  Producto0     Deportes  489.97        77  Proveedor1
# 1  Producto1  Electrónica  347.86        78  Proveedor3
# 2  Producto2         Moda   10.40        93  Proveedor2
# 3  Producto3         Moda  402.25        51  Proveedor3
# 4  Producto4         Moda  445.18        50  Proveedor1
#
#          Fecha de Ingreso  Ubicación
# 0 2025-06-17 00:55:47.643  Almacén B
# 1 2025-03-22 00:55:47.643  Almacén C
# 2 2024-12-28 00:55:47.643  Almacén B
# 3 2025-08-25 00:55:47.643  Almacén A
# 4 2024-12-11 00:55:47.643  Almacén A

# %%
import sqlite3

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Crear lista de tuplas con los datos que se insertarán
datos = []
for _, row in df.iterrows():
    fecha = None
    if pd.notna(row['Fecha de Ingreso']):
        fecha = row['Fecha de Ingreso'].strftime('%Y-%m-%d')
    datos.append((
        row['Nombre'],
        row['Categoría'],
        float(row['Precio']),
        int(row['Cantidad']),
        row.get('Proveedor', None),
        fecha,
        row.get('Ubicación', None)
    ))

# Inserción masiva con executemany (sin incluir 'id' si es autoincremental)
c.executemany("""
    INSERT INTO inventario (nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
    VALUES (?, ?, ?, ?, ?, ?, ?)
""", datos)



# Guardar cambios y cerrar conexión con DB
conn.commit()
conn.close()

print("¡Datos importados exitosamente!")
# Out:
# ¡Datos importados exitosamente!

# %%
import sqlite3
import pandas as pd

# Conexión con la base de datos
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Consulta SQL
consulta = """
SELECT
    categoria,
    SUM(precio * cantidad) AS valor_total
FROM inventario
GROUP BY categoria
ORDER BY valor_total DESC;
"""

# Ejecutar la consulta y obtener los resultados
c.execute(consulta)
resultados = c.fetchall()

# Mostrar los resultados en formato tabular (opcional con pandas)
df_resultados = pd.DataFrame(resultados, columns=["Categoría", "Valor Total"])
print(df_resultados)

# Cerrar la conexión
conn.close()
# Out:
#      Categoría  Valor Total
# 0  Electrónica  39245514.53
# 1         Moda  39165165.14
# 2     Deportes  38512458.15
# 3       Jardín  38257629.83
# 4        Hogar  38191854.18
